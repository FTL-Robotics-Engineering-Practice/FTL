# %% [markdown]
# # Блок 1.1: Знакомство с Python

# %% [markdown]
# # Блок 1.2: Создаем робота через переменные

# %%
# Блок 1.1: Знакомство с Python
# Сегодня мы создадим наших первых роботов!

# Это комментарий - компьютер его игнорирует, а люди читают

# Давайте начнем с простого: научим компьютер "говорить"
print("Привет, мир роботов!")

# TODO: Напишите свое приветствие роботам
print("Hello, robots!")

# Переменные - это "ящики" для хранения информации
robot_name = "KAVA"
robot_age = 18

# Выводим информацию о роботе
print("Имя робота:", robot_name)
print("Возраст робота:", robot_age, "лет")

# TODO: Создайте своего робота с именем и возрастом
my_robot_name = "KAVAKAVASAKI"
my_robot_age = 21

print("Мой робот:", my_robot_name)
print("Его возраст:", my_robot_age)

# Роботы умеют считать!
battery_level = 100
battery_level = battery_level - 10  # робот поработал
print("Заряд батареи:", battery_level, "%")

# TODO: Уменьшите заряд еще на 25% и выведите результат
battery_level = battery_level - 25
print("Заряд после работы:", battery_level, "%")

# %% [markdown]
# # Блок 2.1: Первое знакомство с классами

# %% [markdown]
# # Блок 2.2: Робот учится ходить по квадрату

# %% [markdown]
# # Блок 2.3.1: Красивый вывод информации о роботе

# %% [markdown]
# # Блок 2.3.2: Отдельные методы движения

# %% [markdown]
# # Блок 2.3.3: Автоматическое движение по квадрату

# %% [markdown]
# # Блок 2.3.4: Три робота рисуют квадраты одновременно

# %% [markdown]
# # Блок 1.3: Три робота

# %%
# Блок 1.2: Создаем робота через переменные
# Задача: робот рисует квадрат 3x3

# Создаем робота
robot_name = "Вася"
robot_x = 0  # начальная позиция по горизонтали
robot_y = 0  # начальная позиция по вертикали

print(f"🤖 Робот {robot_name} начинает в точке ({robot_x}, {robot_y})")

# Движение вправо (3 шага)
print("\n🔵 Идем вправо:")
# Шаг 1 вправо
robot_x = robot_x + 1
print(f"Шаг 1: {robot_name} в ({robot_x}, {robot_y})")

# TODO: Добавьте еще 2 шага вправо
# Шаг 2 вправо
robot_x += 1
print(f"Шаг 2: {robot_name} в ({robot_x}, {robot_y})")

# Шаг 3 вправо  
robot_x += 1
print(f"Шаг 3: {robot_name} в ({robot_x}, {robot_y})")

# Движение вверх (3 шага)
print("\n🔵 Идем вверх:")
# TODO: Сделайте 3 шага вверх, выводя позицию после каждого
# Шаг 1 вверх
robot_y += 1
print(f"Шаг 1: {robot_name} в ({robot_x}, {robot_y})")

# Шаг 2 вверх
robot_y += 1
print(f"Шаг 2: {robot_name} в ({robot_x}, {robot_y})")

# Шаг 3 вверх
robot_y += 1
print(f"Шаг 3: {robot_name} в ({robot_x}, {robot_y})")

# Движение влево (3 шага)
print("\n🔵 Идем влево:")
# TODO: Сделайте 3 шага влево
# Подсказка: влево = уменьшать X
robot_x -= 3
print(f"Step 1, 2, 3: {robot_name} в ({robot_x}, {robot_y})")


# Движение вниз (3 шага)  
print("\n🔵 Идем вниз:")
# TODO: Сделайте 3 шага вниз и вернитесь в точку (0, 0)
# Подсказка: вниз = уменьшать Y
robot_y -= 3
print(f"Step 1, 2, 3: {robot_name} в ({robot_x}, {robot_y})")


print(f"\n🏁 Квадрат готов! {robot_name} вернулся в ({robot_x}, {robot_y})")

# Проверка: робот должен вернуться в (0, 0)
if robot_x == 0 and robot_y == 0:
    print("✅ Отлично! Робот вернулся домой!")
else:
    print("❌ Упс! Робот заблудился...")
# Out:
# 🤖 Робот Вася начинает в точке (0, 0)
#
# 🔵 Идем вправо:
# Шаг 1: Вася в (1, 0)
# Шаг 2: Вася в (2, 0)
# Шаг 3: Вася в (3, 0)
#
# 🔵 Идем вверх:
# Шаг 1: Вася в (3, 1)
# Шаг 2: Вася в (3, 2)
# Шаг 3: Вася в (3, 3)
#
# 🔵 Идем влево:
# Step 1, 2, 3: Вася в (0, 3)
#
# 🔵 Идем вниз:
# Step 1, 2, 3: Вася в (0, 0)
#
# 🏁 Квадрат готов! Вася вернулся в (0, 0)
# ✅ Отлично! Робот вернулся домой!

# %%
# Блок 1.3: Три робота - почувствуй боль программиста!
# Задача: создать трех роботов, каждый рисует квадрат из своей стартовой позиции

print("🚀 Запускаем фабрику роботов!")
print("Сегодня у нас работают сразу 3 робота!")

# ========================================
# РОБОТ 1: Альфа
# ========================================
robot1_name = "Альфа"
robot1_x = 0   # стартует из (0, 0)
robot1_y = 0

print(f"\n🤖 Робот {robot1_name} начинает в ({robot1_x}, {robot1_y})")

# Альфа идет вправо (2 шага)
print("Альфа идет вправо:")
robot1_x = robot1_x + 1
print(f"  {robot1_name} в ({robot1_x}, {robot1_y})")
robot1_x = robot1_x + 1  
print(f"  {robot1_name} в ({robot1_x}, {robot1_y})")

# TODO: Заставьте Альфа сделать остальные стороны квадрата 2x2
# Альфа идет вверх (2 шага)
print("Альфа идет вверх:")
robot1_y += 2

# Альфа идет влево (2 шага)
print("Альфа идет влево:")
robot1_x -= 2
# ВАШ КОД ЗДЕСЬ

# Альфа идет вниз (2 шага)
print("Альфа идет вниз:")
robot1_y -= 2
# ВАШ КОД ЗДЕСЬ

print(f"Альфа финишировал в ({robot1_x}, {robot1_y})")

# ========================================
# РОБОТ 2: Бета
# ========================================
robot2_name = "Бета"
robot2_x = 5   # стартует из (5, 5)
robot2_y = 5

print(f"\n🤖 Робот {robot2_name} начинает в ({robot2_x}, {robot2_y})")

# TODO: Заставьте Бета нарисовать квадрат 3x3 из точки (5, 5)
# Скопируйте и измените код от Альфа
# Бета идет вправо (3 шага)
print("Бета идет вправо:")
robot2_x += 3

# Бета идет вверх (3 шага)
print("Бета идет вверх:")
robot2_y += 3

# Бета идет влево (3 шага)
print("Бета идет влево:")
robot2_x -= 3
# ВАШ КОД ЗДЕСЬ

# Бета идет вниз (3 шага)
print("Бета идет вниз:")
robot2_y -= 3
# ВАШ КОД ЗДЕСЬ

print(f"Бета финишировал в ({robot2_x}, {robot2_y})")

# ========================================
# РОБОТ 3: Гамма
# ========================================
robot3_name = "Гамма"
robot3_x = 10  # стартует из (10, 2)
robot3_y = 2

print(f"\n🤖 Робот {robot3_name} начинает в ({robot3_x}, {robot3_y})")

# TODO: Заставьте Гамма нарисовать квадрат 4x4 из точки (10, 2)
# Опять копируйте и изменяйте код...
# ВАШ КОД ЗДЕСЬ - весь код движения для Гамма
print("gamma идет вправо:")
robot3_x += 4

# Бета идет вверх (3 шага)
print("gamma идет вверх:")
robot3_y += 4

# Бета идет влево (3 шага)
print("gamma идет влево:")
robot3_x -= 4
# ВАШ КОД ЗДЕСЬ

# Бета идет вниз (3 шага)
print("Бета идет вниз:")
robot3_y -= 4

print(f"Гамма финишировал в ({robot3_x}, {robot3_y})")

# ========================================
# ПОДВЕДЕНИЕ ИТОГОВ
# ========================================
print(f"\n🏁 ВСЕ РОБОТЫ ЗАВЕРШИЛИ РАБОТУ!")
print(f"📊 Отчет:")
print(f"   {robot1_name}: ({robot1_x}, {robot1_y})")
print(f"   {robot2_name}: ({robot2_x}, {robot2_y})")  
print(f"   {robot3_name}: ({robot3_x}, {robot3_y})")

# Вопросы для размышления:
print(f"\n🤔 ВОПРОСЫ:")
print(f"1. Сколько переменных мы использовали для 3 роботов?")
print(3)
print(f"2. Сколько раз мы копировали похожий код?")
print(2)
print(f"3. Что будет, если нужно изменить логику движения?")
print("change operator settings")
print(f"4. Сколько переменных нужно для 100 роботов?")
print(100)
# Out:
# 🚀 Запускаем фабрику роботов!
# Сегодня у нас работают сразу 3 робота!
#
# 🤖 Робот Альфа начинает в (0, 0)
# Альфа идет вправо:
#   Альфа в (1, 0)
#   Альфа в (2, 0)
# Альфа идет вверх:
# Альфа идет влево:
# Альфа идет вниз:
# Альфа финишировал в (0, 0)
#
# 🤖 Робот Бета начинает в (5, 5)
# Бета идет вправо:
# Бета идет вверх:
# Бета идет влево:
# Бета идет вниз:
# Бета финишировал в (5, 5)
#
# 🤖 Робот Гамма начинает в (10, 2)
# gamma идет вправо:
# gamma идет вверх:
# gamma идет влево:
# Бета идет вниз:
# Гамма финишировал в (10, 2)
#
# 🏁 ВСЕ РОБОТЫ ЗАВЕРШИЛИ РАБОТУ!
# 📊 Отчет:
#    Альфа: (0, 0)
#    Бета: (5, 5)
#    Гамма: (10, 2)
#
# 🤔 ВОПРОСЫ:
# 1. Сколько переменных мы использовали для 3 роботов?
# 3
# 2. Сколько раз мы копировали похожий код?
# 2
# 3. Что будет, если нужно изменить логику движения?
# change operator settings
# 4. Сколько переменных нужно для 100 роботов?
# 100

# %%
# Блок 2.1: Первое знакомство с классами

# Задание 1
# 1) Создайте класс с подходящим именем (придумайте сами)
# 2) В конструктор передайте входные параметры (например, имя и стартовые координаты)
# 3) Создайте один объект и проверьте, что поля правильно сохранились
# 4) Измените поля у объекта и проверьте, что изменения применились

class Robot:
    def __init__(self, name, x, y):
        self.name = name
        self.x = int(x)
        self.y = int(y)

# создайте объект
obj = Robot("Alpha", 0, 0)

# выведите значения полей
print("До изменения:", obj.name, obj.x, obj.y)

# измените поля
obj.name = "Beta"
obj.x = 10
obj.y = 10

# проверьте изменения
print("После изменения:", obj.name, obj.x, obj.y)

print("\n---\n")

# Задание 2
# 1) Создайте два объекта того же класса
# 2) "Передвиньте" их, изменив числовые поля (например, координаты)
# 3) Проверьте, что итоговые значения корректны

obj1 = Robot("Gamma", 0, 0)
obj2 = Robot("Delta", 5, 5)

print("obj1:", obj1.name, obj1.x, obj1.y)
print("obj2:", obj2.name, obj2.x, obj2.y)
print()

# движение: задайте правила и примените
# пример: obj1: +2, +1; obj2: -3, +4
obj1.x += 2
obj1.y += 4

obj2.x += 5
obj2.y -= 8

print("obj1:", obj1.name, obj1.x, obj1.y)
print("obj2:", obj2.name, obj2.x, obj2.y)
# Out:
# До изменения: Alpha 0 0
# После изменения: Beta 10 10
#
# ---
#
# obj1: Gamma 0 0
# obj2: Delta 5 5
#
# obj1: Gamma 2 4
# obj2: Delta 10 -3

# %%
# Блок 2.2: Робот учится ходить по квадрату
# Добавляем методы движения в класс

class Robot:
    """Робот, который умеет ходить по квадрату"""
    
    def __init__(self, name, start_x=0, start_y=0):
        """Создаем робота с именем и стартовой позицией"""
        self.name = name
        self.x = start_x
        self.y = start_y
        print(f"🤖 {name} создан в позиции ({start_x}, {start_y})")
    
    def info(self):
        """Показать информацию о роботе"""
        print(f"🤖 {self.name} находится в ({self.x}, {self.y})")
    
    def walk_square(self, size=3):
        """Робот рисует квадрат заданного размера"""
        print(f"🚶 {self.name} начинает рисовать квадрат {size}x{size}")
        
        # TODO: Заполните код движения робота
        
        

        # Подсказка: используйте self.x и self.y
        
        # Движение вправо (size шагов)
        print(f"  {self.name} идет вправо:")
        for step in range(size):
            self.x += 1  # шаг вправо
            print(f"    Шаг {step+1}: {self.name} в ({self.x}, {self.y})")
        
        # TODO: Движение вверх (size шагов)
        print(f"  {self.name} идет вверх:")
        for step in range(size):
            self.y += 1  # ВАШ КОД: какую координату менять?
            print(f"    Шаг {step+1}: {self.name} в ({self.x}, {self.y})")
        
        # TODO: Движение влево (size шагов)
        print(f"  {self.name} идет влево:")
        for step in range(size):  # ВАШ КОД: сколько шагов?
            self.x -= 1  # ВАШ КОД: как идти влево?
            print(f"    Шаг {step+1}: {self.name} в ({self.x}, {self.y})")
        
        # TODO: Движение вниз (size шагов)
        print(f"  {self.name} идет вниз:")
        for step in range(size):  # ВАШ КОД: сколько шагов?
            self.y -= 1  # ВАШ КОД: как идти 
            print(f"    Шаг {step+1}: {self.name} в ({self.x}, {self.y})")
        # ВАШ КОД: заполните весь цикл для движения вниз
        
        
        print(f"✅ {self.name} завершил квадрат! Финальная позиция: ({self.x}, {self.y})")

# Тестируем нашего робота
print("🚀 ТЕСТ: Один робот рисует квадрат")

# TODO: Создайте робота по имени "Тестер" в позиции (0, 0)
robot = Robot("Tester", 0, 0)

# Показать начальную позицию
robot.info()

# TODO: Заставить робота нарисовать квадрат размером 2x2
robot.walk_square(2)

# Показать финальную позицию
robot.info()

# Проверяем: робот должен вернуться в стартовую позицию
start_x, start_y = 0, 0
assert robot.x == start_x and robot.y == start_y, f"Ожидалось ({start_x},{start_y}), получили ({robot.x},{robot.y})"
print("✅ Отлично! Робот вернулся домой!")

print("\n🎉 Поздравляем! Вы создали робота с методом!")
# Out:
# 🚀 ТЕСТ: Один робот рисует квадрат
# 🤖 Tester создан в позиции (0, 0)
# 🤖 Tester находится в (0, 0)
# 🚶 Tester начинает рисовать квадрат 2x2
#   Tester идет вправо:
#     Шаг 1: Tester в (1, 0)
#     Шаг 2: Tester в (2, 0)
#   Tester идет вверх:
#     Шаг 1: Tester в (2, 1)
#     Шаг 2: Tester в (2, 2)
#   Tester идет влево:
#     Шаг 1: Tester в (1, 2)
#     Шаг 2: Tester в (0, 2)
#   Tester идет вниз:
#     Шаг 1: Tester в (0, 1)
#     Шаг 2: Tester в (0, 0)
# ✅ Tester завершил квадрат! Финальная позиция: (0, 0)
# 🤖 Tester находится в (0, 0)
# ✅ Отлично! Робот вернулся домой!
#
# 🎉 Поздравляем! Вы создали робота с методом!

# %%
# Блок 2.3.1: Красивый вывод информации о роботе

class Robot:
    """Робот с красивым выводом информации"""
    
    def __init__(self, name, start_x=0, start_y=0):
        """Создаем робота с именем и стартовой позицией"""
        self.name = name
        self.x = start_x
        self.y = start_y
        self.start_x = start_x  # запоминаем дом
        self.start_y = start_y
        self.steps_made = 0     # счетчик шагов
        print(f"🤖 {name} создан в позиции ({start_x}, {start_y})")
    
    def show_info(self):
        """Красивый вывод информации о роботе"""
        print(f"┌{'─' * 40}┐")
        print(f"│ 🤖 Робот: {self.name:<28} │")
        print(f"│ 📍 Позиция: ({self.x}, {self.y}){' ' * (23 - len(str(self.x)) - len(str(self.y)))}│")
        print(f"│ 🏠 Дом: ({self.start_x}, {self.start_y}){' ' * (27 - len(str(self.start_x)) - len(str(self.start_y)))}│")
        print(f"│ 👣 Шагов сделано: {self.steps_made:<20} │")
        print(f"└{'─' * 40}┘")
    
    def move_right(self):
        """Движение вправо"""
        self.x += 1
        self.steps_made += 1
        print(f"    👣 {self.name} в ({self.x}, {self.y})")

# Создаем робота и показываем информацию
print("🏭 Создаем робота!")
robot = Robot("Альфа", 5, 3)

print("\n📊 ИНФОРМАЦИЯ О РОБОТЕ:")
# TODO: Вызовите метод show_info() для робота
robot.show_info()

print("\n🚶 Робот делает несколько шагов:")
robot.move_right()
robot.move_right()

print("\n📊 ОБНОВЛЕННАЯ ИНФОРМАЦИЯ:")
# TODO: Снова покажите информацию о роботе
robot.show_info()

print("\n✅ Отлично! Теперь у нас есть красивый способ показать информацию о роботе!")
# Out:
# 🏭 Создаем робота!
# 🤖 Альфа создан в позиции (5, 3)
#
# 📊 ИНФОРМАЦИЯ О РОБОТЕ:
# ┌────────────────────────────────────────┐
# │ 🤖 Робот: Альфа                        │
# │ 📍 Позиция: (5, 3)                     │
# │ 🏠 Дом: (5, 3)                         │
# │ 👣 Шагов сделано: 0                    │
# └────────────────────────────────────────┘
#
# 🚶 Робот делает несколько шагов:
#     👣 Альфа в (6, 3)
#     👣 Альфа в (7, 3)
#
# 📊 ОБНОВЛЕННАЯ ИНФОРМАЦИЯ:
# ┌────────────────────────────────────────┐
# │ 🤖 Робот: Альфа                        │
# │ 📍 Позиция: (7, 3)                     │
# │ 🏠 Дом: (5, 3)                         │
# │ 👣 Шагов сделано: 2                    │
# └────────────────────────────────────────┘
#
# ✅ Отлично! Теперь у нас есть красивый способ показать информацию о роботе!

# %%
# Блок 2.3.2: Отдельные методы движения

class Robot:
    """Робот с отдельными методами движения"""
    
    def __init__(self, name, start_x=0, start_y=0):
        """Создаем робота с именем и стартовой позицией"""
        self.name = name
        self.x = start_x
        self.y = start_y
        self.start_x = start_x
        self.start_y = start_y
        self.steps_made = 0
        print(f"🤖 {name} создан в позиции ({start_x}, {start_y})")
    
    def show_info(self):
        """Красивый вывод информации о роботе"""
        print(f"┌{'─' * 40}┐")
        print(f"│ 🤖 Робот: {self.name:<28} │")
        print(f"│ 📍 Позиция: ({self.x}, {self.y}){' ' * (23 - len(str(self.x)) - len(str(self.y)))}│")
        print(f"│ 🏠 Дом: ({self.start_x}, {self.start_y}){' ' * (27 - len(str(self.start_x)) - len(str(self.start_y)))}│")
        print(f"│ 👣 Шагов сделано: {self.steps_made:<20} │")
        print(f"└{'─' * 40}┘")
    
    def move_right(self, steps=1):
        """Движение вправо на указанное количество шагов"""
        # TODO: Проверьте, что steps > 0
        if steps <= 0:
            print(f"❌ {self.name}: нельзя двигаться на {steps} шагов!")
            return
        if steps > 0:
            print(f"👣 {self.name} движется вправо на {steps} шагов")
        
        # TODO: Реализуйте движение вправо
        for step in range(steps):
            self.x += 1
            self.steps_made += 1
            print(f"    ➡️ {self.name} шаг {step+1} → ({self.x}, {self.y})")
    
    def move_left(self, steps=1):
        """Движение влево на указанное количество шагов"""
        # TODO: Проверьте, что steps > 0
        if steps <= 0:
            print(f"❌ {self.name}: нельзя двигаться на {steps} шагов!")
            return
        if steps > 0:
            print(f"👣 {self.name} движется влево на {steps} шагов")
        
        # TODO: Реализуйте движение влево
        for step in range(steps):
            self.x -= 1
            self.steps_made += 1
            print(f"    ⬅️ {self.name} шаг {step+1} → ({self.x}, {self.y})")
    
    def move_up(self, steps=1):
        """Движение вверх на указанное количество шагов"""
        # TODO: Проверьте, что steps > 0
        if steps <= 0:
            print(f"❌ {self.name}: нельзя двигаться на {steps} шагов!")
            return
        if steps > 0:
            print(f"👣 {self.name} движется вверх на {steps} шагов")
        
        # TODO: Реализуйте движение вверх
        for step in range(steps):
            self.y += 1
            self.steps_made += 1
            print(f"    ⬆️ {self.name} шаг {step+1} → ({self.x}, {self.y})")
    
    def move_down(self, steps=1):
        """Движение вниз на указанное количество шагов"""
        # TODO: Проверьте, что steps > 0
        if steps <= 0:
            print(f"❌ {self.name}: нельзя двигаться на {steps} шагов!")
            return
        if steps > 0:
            print(f"👣 {self.name} движется вниз на {steps} шагов")
        
        # TODO: Реализуйте движение вниз
        for step in range(steps):
            self.y -= 1
            self.steps_made += 1
            print(f"    ⬇️ {self.name} шаг {step+1} → ({self.x}, {self.y})")

# Создаем робота
print("🏭 Создаем робота!")
robot = Robot("Бета", 0, 0)

print("\n📊 НАЧАЛЬНОЕ СОСТОЯНИЕ:")
robot.show_info()

print("\n🎮 УПРАВЛЯЕМ РОБОТОМ ОТДЕЛЬНЫМИ МЕТОДАМИ:")
# TODO: Заставьте робота двигаться разными методами
robot.move_right(2)  # 2 шага вправо
robot.move_up(3)     # 3 шага вверх
robot.move_left(1)   # 1 шаг влево
robot.move_down(2)   # 2 шага вниз

print("\n🧪 ТЕСТИРУЕМ ОШИБКИ:")
# TODO: Попробуйте отрицательные шаги - что произойдет?
robot.move_right(-2)

print("\n📊 ФИНАЛЬНОЕ СОСТОЯНИЕ:")
robot.show_info()

print("\n✅ Отлично! Теперь мы можем управлять роботом отдельными методами!")
print("💡 Не забудьте добавить проверку количества шагов!")
# Out:
# 🏭 Создаем робота!
# 🤖 Бета создан в позиции (0, 0)
#
# 📊 НАЧАЛЬНОЕ СОСТОЯНИЕ:
# ┌────────────────────────────────────────┐
# │ 🤖 Робот: Бета                         │
# │ 📍 Позиция: (0, 0)                     │
# │ 🏠 Дом: (0, 0)                         │
# │ 👣 Шагов сделано: 0                    │
# └────────────────────────────────────────┘
#
# 🎮 УПРАВЛЯЕМ РОБОТОМ ОТДЕЛЬНЫМИ МЕТОДАМИ:
# 👣 Бета движется вправо на 2 шагов
#     ➡️ Бета шаг 1 → (1, 0)
#     ➡️ Бета шаг 2 → (2, 0)
# 👣 Бета движется вверх на 3 шагов
#     ⬆️ Бета шаг 1 → (2, 1)
#     ⬆️ Бета шаг 2 → (2, 2)
#     ⬆️ Бета шаг 3 → (2, 3)
# 👣 Бета движется влево на 1 шагов
#     ⬅️ Бета шаг 1 → (1, 3)
# 👣 Бета движется вниз на 2 шагов
#     ⬇️ Бета шаг 1 → (1, 2)
#     ⬇️ Бета шаг 2 → (1, 1)
#
# 🧪 ТЕСТИРУЕМ ОШИБКИ:
# ❌ Бета: нельзя двигаться на -2 шагов!
#
# 📊 ФИНАЛЬНОЕ СОСТОЯНИЕ:
# ┌────────────────────────────────────────┐
# │ 🤖 Робот: Бета                         │
# │ 📍 Позиция: (1, 1)                     │
# │ 🏠 Дом: (0, 0)                         │
# │ 👣 Шагов сделано: 8                    │
# └────────────────────────────────────────┘
#
# ✅ Отлично! Теперь мы можем управлять роботом отдельными методами!
# 💡 Не забудьте добавить проверку количества шагов!

# %%
# Блок 2.3.3: Автоматическое движение по квадрату




class Robot:
    """Робот с методом рисования квадрата"""
    
    def __init__(self, name, start_x=0, start_y=0):
        """Создаем робота с именем и стартовой позицией"""
        self.name = name
        self.x = start_x
        self.y = start_y
        self.start_x = start_x
        self.start_y = start_y
        self.steps_made = 0
        print(f"🤖 {name} создан в позиции ({start_x}, {start_y})")
    
    def show_info(self):
        """Красивый вывод информации о роботе"""
        print(f"┌{'─' * 40}┐")
        print(f"│ 🤖 Робот: {self.name:<28} │")
        print(f"│ 📍 Позиция: ({self.x}, {self.y}){' ' * (23 - len(str(self.x)) - len(str(self.y)))}│")
        print(f"│ 🏠 Дом: ({self.start_x}, {self.start_y}){' ' * (27 - len(str(self.start_x)) - len(str(self.start_y)))}│")
        print(f"│ 👣 Шагов сделано: {self.steps_made:<20} │")
        print(f"└{'─' * 40}┘")
    
    def move_right(self, steps=1):
        """Движение вправо на указанное количество шагов"""
        if steps <= 0:
            print(f"❌ {self.name}: нельзя двигаться на {steps} шагов!")
            return
        
        for step in range(steps):
            self.x += 1
            self.steps_made += 1
            print(f"    ➡️ {self.name} шаг {step+1} → ({self.x}, {self.y})")
    
    def move_left(self, steps=1):
        """Движение влево на указанное количество шагов"""
        if steps <= 0:
            print(f"❌ {self.name}: нельзя двигаться на {steps} шагов!")
            return
        
        for step in range(steps):
            self.x -= 1
            self.steps_made += 1
            print(f"    ⬅️ {self.name} шаг {step+1} → ({self.x}, {self.y})")
    
    def move_up(self, steps=1):
        """Движение вверх на указанное количество шагов"""
        if steps <= 0:
            print(f"❌ {self.name}: нельзя двигаться на {steps} шагов!")
            return
        
        for step in range(steps):
            self.y += 1
            self.steps_made += 1
            print(f"    ⬆️ {self.name} шаг {step+1} → ({self.x}, {self.y})")
    
    def move_down(self, steps=1):
        """Движение вниз на указанное количество шагов"""
        if steps <= 0:
            print(f"❌ {self.name}: нельзя двигаться на {steps} шагов!")
            return
        
        for step in range(steps):
            self.y -= 1
            self.steps_made += 1
            print(f"    ⬇️ {self.name} шаг {step+1} → ({self.x}, {self.y})")
    
    def walk_square(self, size=3):
        """Робот рисует квадрат заданного размера"""
        print(f"\n🎨 {self.name} начинает рисовать квадрат {size}x{size}")
        
        # Вправо
        print(f"  ➡️ Идем вправо ({size} шагов):")
        self.move_right(size)
        
        # TODO: Заполните движение вверх
        print(f"  ⬆️ Идем вверх ({size} шагов):")
        self.move_up(size)
        
        # TODO: Заполните движение влево  
        print(f"  ⬅️ Идем влево ({size} шагов):")
        self.move_left(size)
        
        # TODO: Заполните движение вниз
        print(f"  ⬇️ Идем вниз ({size} шагов):")
        self.move_down(size)
        
        print(f"✅ {self.name} завершил квадрат!")

# Создаем робота
print("🏭 Создаем робота!")
robot = Robot("Гамма", 0, 0)

print("\n📊 НАЧАЛЬНОЕ СОСТОЯНИЕ:")
robot.show_info()

print("\n🎨 РИСУЕМ КВАДРАТЫ РАЗНОГО РАЗМЕРА:")

# TODO: Заставьте робота нарисовать квадрат 2x2
robot.walk_square(2)

print("\n📊 СОСТОЯНИЕ ПОСЛЕ ПЕРВОГО КВАДРАТА:")
robot.show_info()

# TODO: Заставьте робота нарисовать квадрат 4x4
robot.walk_square(4)

print("\n📊 ФИНАЛЬНОЕ СОСТОЯНИЕ:")
robot.show_info()

# Проверка: вернулся ли робот домой?
print("\n🏠 ПРОВЕРКА: ВЕРНУЛСЯ ЛИ РОБОТ ДОМОЙ?")
if robot.x == robot.start_x and robot.y == robot.start_y:
    print(f"✅ {robot.name} вернулся домой!")
else:
    print(f"❌ {robot.name} заблудился!")

print("\n✅ Отлично! Теперь робот может автоматически рисовать квадраты!")
# Out:
# 🏭 Создаем робота!
# 🤖 Гамма создан в позиции (0, 0)
#
# 📊 НАЧАЛЬНОЕ СОСТОЯНИЕ:
# ┌────────────────────────────────────────┐
# │ 🤖 Робот: Гамма                        │
# │ 📍 Позиция: (0, 0)                     │
# │ 🏠 Дом: (0, 0)                         │
# │ 👣 Шагов сделано: 0                    │
# └────────────────────────────────────────┘
#
# 🎨 РИСУЕМ КВАДРАТЫ РАЗНОГО РАЗМЕРА:
#
# 🎨 Гамма начинает рисовать квадрат 2x2
#   ➡️ Идем вправо (2 шагов):
#     ➡️ Гамма шаг 1 → (1, 0)
#     ➡️ Гамма шаг 2 → (2, 0)
#   ⬆️ Идем вверх (2 шагов):
#     ⬆️ Гамма шаг 1 → (2, 1)
#     ⬆️ Гамма шаг 2 → (2, 2)
#   ⬅️ Идем влево (2 шагов):
#     ⬅️ Гамма шаг 1 → (1, 2)
#     ⬅️ Гамма шаг 2 → (0, 2)
#   ⬇️ Идем вниз (2 шагов):
#     ⬇️ Гамма шаг 1 → (0, 1)
#     ⬇️ Гамма шаг 2 → (0, 0)
# ✅ Гамма завершил квадрат!
#
# 📊 СОСТОЯНИЕ ПОСЛЕ ПЕРВОГО КВАДРАТА:
# ┌────────────────────────────────────────┐
# │ 🤖 Робот: Гамма                        │
# │ 📍 Позиция: (0, 0)                     │
# │ 🏠 Дом: (0, 0)                         │
# │ 👣 Шагов сделано: 8                    │
# └────────────────────────────────────────┘
#
# 🎨 Гамма начинает рисовать квадрат 4x4
#   ➡️ Идем вправо (4 шагов):
#     ➡️ Гамма шаг 1 → (1, 0)
#     ➡️ Гамма шаг 2 → (2, 0)
#     ➡️ Гамма шаг 3 → (3, 0)
#     ➡️ Гамма шаг 4 → (4, 0)
#   ⬆️ Идем вверх (4 шагов):
#     ⬆️ Гамма шаг 1 → (4, 1)
#     ⬆️ Гамма шаг 2 → (4, 2)
#     ⬆️ Гамма шаг 3 → (4, 3)
#     ⬆️ Гамма шаг 4 → (4, 4)
#   ⬅️ Идем влево (4 шагов):
#     ⬅️ Гамма шаг 1 → (3, 4)
#     ⬅️ Гамма шаг 2 → (2, 4)
#     ⬅️ Гамма шаг 3 → (1, 4)
#     ⬅️ Гамма шаг 4 → (0, 4)
#   ⬇️ Идем вниз (4 шагов):
#     ⬇️ Гамма шаг 1 → (0, 3)
#     ⬇️ Гамма шаг 2 → (0, 2)
#     ⬇️ Гамма шаг 3 → (0, 1)
#     ⬇️ Гамма шаг 4 → (0, 0)
# ✅ Гамма завершил квадрат!
#
# 📊 ФИНАЛЬНОЕ СОСТОЯНИЕ:
# ┌────────────────────────────────────────┐
# │ 🤖 Робот: Гамма                        │
# │ 📍 Позиция: (0, 0)                     │
# │ 🏠 Дом: (0, 0)                         │
# │ 👣 Шагов сделано: 24                   │
# └────────────────────────────────────────┘
#
# 🏠 ПРОВЕРКА: ВЕРНУЛСЯ ЛИ РОБОТ ДОМОЙ?
# ✅ Гамма вернулся домой!
#
# ✅ Отлично! Теперь робот может автоматически рисовать квадраты!

# %% [markdown]
# class Robot:
#     def __init__(self, name, x=0, y=0):
#         self.name = name
#         self.x = x
#         self.y = y
#         self.history = []  # История: [(x, y), (x, y), ...]
#         # TODO: Сохранить начальную позицию в историю
#
#     def command(self, cmd):
#         """Выполняет команду: 'up', 'down', 'left', 'right'"""
#         if cmd == "up":
#             # TODO: изменить y, сохранить в историю
#             pass
#         elif cmd == "down":
#             # TODO: изменить y, сохранить в историю
#             pass
#         elif cmd == "left":
#             # TODO: изменить x, сохранить в историю
#             pass
#         elif cmd == "right":
#             # TODO: изменить x, сохранить в историю
#             pass
#
#     def show_history(self):
#         """Показывает всю историю движения"""
#         # TODO: вывести все позиции из self.history
#         pass
#
# # Тест в ячейке:
# print("🧪 ТЕСТ 1.1: История состояний")
# robot = Robot("Тест", 0, 0)
# robot.command("right")
# robot.command("right")
# robot.command("up")
# robot.show_history()
#
# # Автоматическая проверка результата:
# expected_history = [(0,0), (1,0), (2,0), (2,1)]
# if robot.history == expected_history:
#     print("✅ ТЕСТ ПРОЙДЕН: История корректна")
# else:
#     print(f"❌ ТЕСТ НЕ ПРОЙДЕН: Ожидалось {expected_history}, получено {robot.history}")
#
# # Дополнительный тест - возврат домой:
# robot2 = Robot("Тест2", 5, 3)
# robot2.command("left")
# robot2.command("down")
# robot2.command("right")
# robot2.command("up")
#
# expected_history2 = [(5,3), (4,3), (4,2), (5,2), (5,3)]
# if robot2.history == expected_history2:
#     print("✅ ДОПОЛНИТЕЛЬНЫЙ ТЕСТ ПРОЙДЕН: Возврат в исходную точку")
# else:
#     print(f"❌ ДОПОЛНИТЕЛЬНЫЙ ТЕСТ НЕ ПРОЙДЕН: Ожидалось {expected_history2}, получено {robot2.history}")

# %%
# Блок 2.3.4: Три робота рисуют квадраты одновременно

class Robot:
    """Продвинутый робот с красивым выводом информации"""
    
    def __init__(self, name, start_x=0, start_y=0):
        """Создаем робота с именем и стартовой позицией"""
        self.name = name
        self.x = start_x
        self.y = start_y
        self.start_x = start_x  # запоминаем дом
        self.start_y = start_y
        self.steps_made = 0     # счетчик шагов
        print(f"🤖 {name} создан в позиции ({start_x}, {start_y})")
    
    def show_info(self):
        """Красивый вывод информации о роботе"""
        print(f"┌{'─' * 40}┐")
        print(f"│ 🤖 Робот: {self.name:<28} │")
        print(f"│ 📍 Позиция: ({self.x}, {self.y}){' ' * (23 - len(str(self.x)) - len(str(self.y)))}│")
        print(f"│ 🏠 Дом: ({self.start_x}, {self.start_y}){' ' * (27 - len(str(self.start_x)) - len(str(self.start_y)))}│")
        print(f"│ 👣 Шагов сделано: {self.steps_made:<20} │")
        print(f"└{'─' * 40}┘")
    
    def move_right(self, steps=1):
        """Движение вправо на указанное количество шагов"""
        if steps <= 0:
            print(f"❌ {self.name}: нельзя двигаться на {steps} шагов!")
            return
        
        for step in range(steps):
            self.x += 1
            self.steps_made += 1
            print(f"    ➡️ {self.name} шаг {step+1} → ({self.x}, {self.y})")
    
    def move_left(self, steps=1):
        """Движение влево на указанное количество шагов"""
        if steps <= 0:
            print(f"❌ {self.name}: нельзя двигаться на {steps} шагов!")
            return
        
        for step in range(steps):
            self.x -= 1
            self.steps_made += 1
            print(f"    ⬅️ {self.name} шаг {step+1} → ({self.x}, {self.y})")
    
    def move_up(self, steps=1):
        """Движение вверх на указанное количество шагов"""
        if steps <= 0:
            print(f"❌ {self.name}: нельзя двигаться на {steps} шагов!")
            return
        
        for step in range(steps):
            self.y += 1
            self.steps_made += 1
            print(f"    ⬆️ {self.name} шаг {step+1} → ({self.x}, {self.y})")
    
    def move_down(self, steps=1):
        """Движение вниз на указанное количество шагов"""
        if steps <= 0:
            print(f"❌ {self.name}: нельзя двигаться на {steps} шагов!")
            return
        
        for step in range(steps):
            self.y -= 1
            self.steps_made += 1
            print(f"    ⬇️ {self.name} шаг {step+1} → ({self.x}, {self.y})")
    
    def walk_square(self, size=3):
        """Робот рисует квадрат заданного размера"""
        print(f"\n🎨 {self.name} начинает рисовать квадрат {size}x{size}")
        
        # Вправо
        print(f"  ➡️ Идем вправо ({size} шагов):")
        self.move_right(size)
        
        # Вверх
        print(f"  ⬆️ Идем вверх ({size} шагов):")
        self.move_up(size)
        
        # Влево
        print(f"  ⬅️ Идем влево ({size} шагов):")
        self.move_left(size)
        
        # Вниз
        print(f"  ⬇️ Идем вниз ({size} шагов):")
        self.move_down(size)
        
        print(f"✅ {self.name} завершил квадрат!")

# Создаем трех роботов в разных позициях
print("🏭 Запускаем фабрику роботов!")

# TODO: Создайте трех роботов
# Робот 1: "Альфа" в позиции (0, 0)
robot1 = Robot("Alpha", 0, 0)

# Робот 2: "Бета" в позиции (10, 5)  
robot2 = Robot("Beta", 10, 5)

# Робот 3: "Гамма" в позиции (20, 10)
robot3 = Robot("Gamma", 20, 10)

# Показать начальную информацию
print("\n📊 НАЧАЛЬНОЕ СОСТОЯНИЕ РОБОТОВ:")
# TODO: Вызвать show_info() для каждого робота
robot1.show_info()
robot2.show_info()
robot3.show_info()

# Запустить всех роботов рисовать
print("\n🎨 ВСЕ РОБОТЫ НАЧИНАЮТ РИСОВАТЬ:")

# TODO: Заставить каждого робота нарисовать квадрат разного размера
# Альфа рисует квадрат 2x2
robot1.walk_square(2)

# Бета рисует квадрат 3x3
robot2.walk_square(3)

# Гамма рисует квадрат 4x4  
robot3.walk_square(4)

# Показать финальную информацию
print("\n📊 ФИНАЛЬНОЕ СОСТОЯНИЕ РОБОТОВ:")
# TODO: Снова показать информацию о всех роботах
robot1.show_info()
robot2.show_info()
robot3.show_info()

# Проверка: кто вернулся домой?
print("\n🏠 ПРОВЕРКА: КТО ВЕРНУЛСЯ ДОМОЙ?")
robots = [robot1, robot2, robot3]
for robot in robots:
    if robot.x == robot.start_x and robot.y == robot.start_y:
        print(f"✅ {robot.name} вернулся домой!")
    else:
        print(f"❌ {robot.name} заблудился!")

print(f"\n🎉 Задание выполнено! Мы управляли {len(robots)} роботами одновременно!")
# Out:
# 🏭 Запускаем фабрику роботов!
# 🤖 Alpha создан в позиции (0, 0)
# 🤖 Beta создан в позиции (10, 5)
# 🤖 Gamma создан в позиции (20, 10)
#
# 📊 НАЧАЛЬНОЕ СОСТОЯНИЕ РОБОТОВ:
# ┌────────────────────────────────────────┐
# │ 🤖 Робот: Alpha                        │
# │ 📍 Позиция: (0, 0)                     │
# │ 🏠 Дом: (0, 0)                         │
# │ 👣 Шагов сделано: 0                    │
# └────────────────────────────────────────┘
# ┌────────────────────────────────────────┐
# │ 🤖 Робот: Beta                         │
# │ 📍 Позиция: (10, 5)                    │
# │ 🏠 Дом: (10, 5)                        │
# │ 👣 Шагов сделано: 0                    │
# └────────────────────────────────────────┘
# ┌────────────────────────────────────────┐
# │ 🤖 Робот: Gamma                        │
# │ 📍 Позиция: (20, 10)                   │
# │ 🏠 Дом: (20, 10)                       │
# │ 👣 Шагов сделано: 0                    │
# └────────────────────────────────────────┘
#
# 🎨 ВСЕ РОБОТЫ НАЧИНАЮТ РИСОВАТЬ:
#
# 🎨 Alpha начинает рисовать квадрат 2x2
#   ➡️ Идем вправо (2 шагов):
#     ➡️ Alpha шаг 1 → (1, 0)
#     ➡️ Alpha шаг 2 → (2, 0)
#   ⬆️ Идем вверх (2 шагов):
#     ⬆️ Alpha шаг 1 → (2, 1)
#     ⬆️ Alpha шаг 2 → (2, 2)
#   ⬅️ Идем влево (2 шагов):
#     ⬅️ Alpha шаг 1 → (1, 2)
#     ⬅️ Alpha шаг 2 → (0, 2)
#   ⬇️ Идем вниз (2 шагов):
#     ⬇️ Alpha шаг 1 → (0, 1)
#     ⬇️ Alpha шаг 2 → (0, 0)
# ✅ Alpha завершил квадрат!
#
# 🎨 Beta начинает рисовать квадрат 3x3
#   ➡️ Идем вправо (3 шагов):
#     ➡️ Beta шаг 1 → (11, 5)
#     ➡️ Beta шаг 2 → (12, 5)
#     ➡️ Beta шаг 3 → (13, 5)
#   ⬆️ Идем вверх (3 шагов):
#     ⬆️ Beta шаг 1 → (13, 6)
#     ⬆️ Beta шаг 2 → (13, 7)
#     ⬆️ Beta шаг 3 → (13, 8)
#   ⬅️ Идем влево (3 шагов):
#     ⬅️ Beta шаг 1 → (12, 8)
#     ⬅️ Beta шаг 2 → (11, 8)
#     ⬅️ Beta шаг 3 → (10, 8)
#   ⬇️ Идем вниз (3 шагов):
#     ⬇️ Beta шаг 1 → (10, 7)
#     ⬇️ Beta шаг 2 → (10, 6)
#     ⬇️ Beta шаг 3 → (10, 5)
# ✅ Beta завершил квадрат!
#
# 🎨 Gamma начинает рисовать квадрат 4x4
#   ➡️ Идем вправо (4 шагов):
#     ➡️ Gamma шаг 1 → (21, 10)
#     ➡️ Gamma шаг 2 → (22, 10)
#     ➡️ Gamma шаг 3 → (23, 10)
#     ➡️ Gamma шаг 4 → (24, 10)
#   ⬆️ Идем вверх (4 шагов):
#     ⬆️ Gamma шаг 1 → (24, 11)
#     ⬆️ Gamma шаг 2 → (24, 12)
#     ⬆️ Gamma шаг 3 → (24, 13)
#     ⬆️ Gamma шаг 4 → (24, 14)
#   ⬅️ Идем влево (4 шагов):
#     ⬅️ Gamma шаг 1 → (23, 14)
#     ⬅️ Gamma шаг 2 → (22, 14)
#     ⬅️ Gamma шаг 3 → (21, 14)
#     ⬅️ Gamma шаг 4 → (20, 14)
#   ⬇️ Идем вниз (4 шагов):
#     ⬇️ Gamma шаг 1 → (20, 13)
#     ⬇️ Gamma шаг 2 → (20, 12)
#     ⬇️ Gamma шаг 3 → (20, 11)
#     ⬇️ Gamma шаг 4 → (20, 10)
# ✅ Gamma завершил квадрат!
#
# 📊 ФИНАЛЬНОЕ СОСТОЯНИЕ РОБОТОВ:
# ┌────────────────────────────────────────┐
# │ 🤖 Робот: Alpha                        │
# │ 📍 Позиция: (0, 0)                     │
# │ 🏠 Дом: (0, 0)                         │
# │ 👣 Шагов сделано: 8                    │
# └────────────────────────────────────────┘
# ┌────────────────────────────────────────┐
# │ 🤖 Робот: Beta                         │
# │ 📍 Позиция: (10, 5)                    │
# │ 🏠 Дом: (10, 5)                        │
# │ 👣 Шагов сделано: 12                   │
# └────────────────────────────────────────┘
# ┌────────────────────────────────────────┐
# │ 🤖 Робот: Gamma                        │
# │ 📍 Позиция: (20, 10)                   │
# │ 🏠 Дом: (20, 10)                       │
# │ 👣 Шагов сделано: 16                   │
# └────────────────────────────────────────┘
#
# 🏠 ПРОВЕРКА: КТО ВЕРНУЛСЯ ДОМОЙ?
# ✅ Alpha вернулся домой!
# ✅ Beta вернулся домой!
# ✅ Gamma вернулся домой!
#
# 🎉 Задание выполнено! Мы управляли 3 роботами одновременно!

# %%
# Блок 3.1: Фабрика роботов - массовое производство!
# Создаем много роботов из списка данных

class Robot:
    """Робот для массового производства"""
    
    def __init__(self, name, start_x=0, start_y=0, color="blue"):
        self.name = name
        self.x = start_x
        self.y = start_y
        self.start_x = start_x
        self.start_y = start_y
        self.color = color
        self.steps_made = 0
        print(f"🤖 {name} ({color}) создан в ({start_x}, {start_y})")
    
    def show_info(self):
        """Компактный вывод информации"""
        status = "🏠" if (self.x == self.start_x and self.y == self.start_y) else "🗺️"
        print(f"{status} {self.name:<10} | Позиция: ({self.x:2}, {self.y:2}) | Шагов: {self.steps_made:2} | Цвет: {self.color}")
    
    def walk_square(self, size=3):
        """Быстрое рисование квадрата (без детального вывода)"""
        directions = ["right", "up", "left", "down"]
        
        for direction in directions:
            for step in range(size):
                if direction == "right":
                    self.x += 1
                elif direction == "up":
                    self.y += 1
                elif direction == "left":
                    self.x -= 1
                elif direction == "down":
                    self.y -= 1
                self.steps_made += 1
        
        print(f"✅ {self.name} завершил квадрат {size}x{size}")

# База данных роботов для создания концентрических квадратов
# Каждый словарь должен содержать: "name", "x", "y", "color"
# Стартовые позиции и размеры подобраны так, чтобы получились концентрические квадраты
robots_data = [
    # TODO: Заполните словари данными для роботов
    # Стартовые позиции: (0,0), (1,1), (2,2)
    # Цвета можете выбрать любые
    {"name": "Alpha", "x": 0, "y": 0, "color": "blue"},
    {"name": "Beta", "x": 1, "y": 1, "color": "red"},
    {"name": "Gamma", "x": 2, "y": 2, "color": "green"}
]

print("🏭 ФАБРИКА РОБОТОВ ЗАПУЩЕНА!")
print(f"📋 В очереди на производство: {len(robots_data)} роботов")

# TODO: Создайте всех роботов из списка данных
robot_army = []  # список для хранения роботов

print("\n🔧 ПРОИЗВОДСТВО РОБОТОВ:")
for robot_data in robots_data:
    # TODO: Создайте робота из данных словаря
    # Подсказка: robot_data["name"], robot_data["x"], и т.д.
    robot = Robot(
        robot_data["name"],    # имя
        robot_data["x"],    # x координата  
        robot_data["y"],    # y координата
        robot_data["color"]     # цвет
    )
    robot_army.append(robot)

print(f"\n✅ Произведено роботов: {len(robot_army)}")

# Показать информацию о всех роботах
print("\n📊 РЕЕСТР РОБОТОВ:")
print("   Статус | Имя        | Позиция    | Шагов | Цвет")
print("   " + "─" * 50)

# TODO: Покажите информацию о каждом роботе
for robot in robot_army:
    robot.show_info()

# Запустить всех роботов работать
print("\n🎨 МАССОВОЕ ПРОИЗВОДСТВО КВАДРАТОВ:")

# TODO: Заставьте всех роботов нарисовать квадраты разного размера
# Для концентрических квадратов используйте размеры: 4, 3, 2
sizes = [4, 3, 2]  # размеры квадратов для концентрических квадратов

for i, robot in enumerate(robot_army):
    size = sizes[i]
    print(f"🤖 {robot.name} рисует квадрат {size}x{size}...")
    robot.walk_square(size)

# Финальная статистика
print("\n📊 ФИНАЛЬНАЯ СТАТИСТИКА:")
print("   Статус | Имя        | Позиция    | Шагов | Цвет") 
print("   " + "─" * 50)

# TODO: Снова покажите информацию о всех роботах
for robot in robot_army:
    robot.show_info()

# Анализ результатов  
print(f"\n📈 АНАЛИЗ ПРОИЗВОДСТВА:")

# TODO: Подсчитайте статистику
total_steps = 0
robots_at_home = 0

for robot in robot_army:
    total_steps += robot.steps_made # добавьте шаги робота
    
    # Проверьте, дома ли робот
    if robot.x == robot.start_x and robot.y == robot.start_y:
        robots_at_home += 1

print(f"   🤖 Всего роботов: {len(robot_army)}")
print(f"   👣 Общее количество шагов: {total_steps}")
print(f"   📊 Среднее шагов на робота: {total_steps / len(robot_army):.1f}")
print(f"   🏠 Роботов вернулось домой: {robots_at_home}")
print(f"   📏 Эффективность возврата: {robots_at_home / len(robot_army) * 100:.1f}%")

# Поиск чемпионов
most_active = max(robot_army, key=lambda r: r.steps_made)
print(f"   🏆 Самый активный: {most_active.name} ({most_active.steps_made} шагов)")

print(f"\n🎉 ФАБРИКА ЗАВЕРШИЛА РАБОТУ! Все роботы готовы к службе!")
# Out:
# 🏭 ФАБРИКА РОБОТОВ ЗАПУЩЕНА!
# 📋 В очереди на производство: 3 роботов
#
# 🔧 ПРОИЗВОДСТВО РОБОТОВ:
# 🤖 Alpha (blue) создан в (0, 0)
# 🤖 Beta (red) создан в (1, 1)
# 🤖 Gamma (green) создан в (2, 2)
#
# ✅ Произведено роботов: 3
#
# 📊 РЕЕСТР РОБОТОВ:
#    Статус | Имя        | Позиция    | Шагов | Цвет
#    ──────────────────────────────────────────────────
# 🏠 Alpha      | Позиция: ( 0,  0) | Шагов:  0 | Цвет: blue
# 🏠 Beta       | Позиция: ( 1,  1) | Шагов:  0 | Цвет: red
# 🏠 Gamma      | Позиция: ( 2,  2) | Шагов:  0 | Цвет: green
#
# 🎨 МАССОВОЕ ПРОИЗВОДСТВО КВАДРАТОВ:
# 🤖 Alpha рисует квадрат 4x4...
# ✅ Alpha завершил квадрат 4x4
# 🤖 Beta рисует квадрат 3x3...
# ✅ Beta завершил квадрат 3x3
# 🤖 Gamma рисует квадрат 2x2...
# ✅ Gamma завершил квадрат 2x2
#
# 📊 ФИНАЛЬНАЯ СТАТИСТИКА:
#    Статус | Имя        | Позиция    | Шагов | Цвет
#    ──────────────────────────────────────────────────
#
# 📈 АНАЛИЗ ПРОИЗВОДСТВА:
#    🤖 Всего роботов: 3
#    👣 Общее количество шагов: 36
#    📊 Среднее шагов на робота: 12.0
#    🏠 Роботов вернулось домой: 3
#    📏 Эффективность возврата: 100.0%
#    🏆 Самый активный: Alpha (16 шагов)
#
# 🎉 ФАБРИКА ЗАВЕРШИЛА РАБОТУ! Все роботы готовы к службе!

# %%
# Блок 3.2.1: Рисование одного робота с помощью matplotlib
# Учимся рисовать робота на экране!

import matplotlib.pyplot as plt
import numpy as np

class Robot:
    """Робот, который умеет рисовать себя на экране"""
    
    def __init__(self, name, start_x=0, start_y=0, color="blue"):
        self.name = name
        self.x = start_x
        self.y = start_y
        self.start_x = start_x
        self.start_y = start_y
        self.color = color
        self.steps_made = 0
        print(f"🤖 {name} ({color}) создан в ({start_x}, {start_y})")
    
    def draw(self, size=100):
        """Рисует робота на текущем графике"""
        # TODO: Нарисуйте робота как точку
        # Подсказка: используйте plt.scatter()
        plt.scatter(self.x, self.y, 
                   color=self.color, 
                   s=size, 
                   alpha=0.8,
                   label=self.name)
        
        # TODO: Добавьте подпись с именем и координатами
        # Подсказка: используйте plt.annotate()
        plt.annotate(f'{self.name}\n({self.x},{self.y})', 
                    (self.x, self.y), 
                    xytext=(10, 10), 
                    textcoords='offset points',
                    fontsize=8,
                    bbox=dict(boxstyle="round,pad=0.3", 
                             facecolor=self.color, 
                             alpha=0.3))
    
    def move_right(self, steps=1):
        """Движение вправо на указанное количество шагов"""
        if steps <= 0:
            print(f"❌ {self.name}: нельзя двигаться на {steps} шагов!")
            return
        
        for step in range(steps):
            self.x += 1
            self.steps_made += 1
            print(f"    ➡️ {self.name} шаг {step+1} → ({self.x}, {self.y})")
    
    def move_left(self, steps=1):
        """Движение влево на указанное количество шагов"""
        if steps <= 0:
            print(f"❌ {self.name}: нельзя двигаться на {steps} шагов!")
            return
        
        for step in range(steps):
            self.x -= 1
            self.steps_made += 1
            print(f"    ⬅️ {self.name} шаг {step+1} → ({self.x}, {self.y})")
    
    def move_up(self, steps=1):
        """Движение вверх на указанное количество шагов"""
        if steps <= 0:
            print(f"❌ {self.name}: нельзя двигаться на {steps} шагов!")
            return
        
        for step in range(steps):
            self.y += 1
            self.steps_made += 1
            print(f"    ⬆️ {self.name} шаг {step+1} → ({self.x}, {self.y})")
    
    def move_down(self, steps=1):
        """Движение вниз на указанное количество шагов"""
        if steps <= 0:
            print(f"❌ {self.name}: нельзя двигаться на {steps} шагов!")
            return
        
        for step in range(steps):
            self.y -= 1
            self.steps_made += 1
            print(f"    ⬇️ {self.name} шаг {step+1} → ({self.x}, {self.y})")
    
    def walk_square(self, size=3):
        """Робот рисует квадрат заданного размера"""
        print(f"\n🎨 {self.name} начинает рисовать квадрат {size}x{size}")
        
        # Вправо
        print(f"  ➡️ Идем вправо ({size} шагов):")
        self.move_right(size)
        
        # Вверх
        print(f"  ⬆️ Идем вверх ({size} шагов):")
        self.move_up(size)
        
        # Влево
        print(f"  ⬅️ Идем влево ({size} шагов):")
        self.move_left(size)
        
        # Вниз
        print(f"  ⬇️ Идем вниз ({size} шагов):")
        self.move_down(size)
        
        print(f"✅ {self.name} завершил квадрат!")

# Тест: Рисуем одного робота
print("🎨 ТЕСТ: Рисование одного робота")

# TODO: Создайте робота для тестирования
test_robot = Robot("alpha", 0, 0, "blue")

# Настраиваем график
plt.figure(figsize=(8, 6))

# TODO: Нарисуйте робота
test_robot.draw()

# Настройки графика
plt.grid(True, alpha=0.3)
plt.xlim(-2, 10)
plt.ylim(-2, 8)
plt.title("🤖 Мой первый робот на экране!")
plt.xlabel("X координата")
plt.ylabel("Y координата")
plt.legend()
plt.show()

print("✅ Тест завершен! Робот нарисован!")

# Дополнительное задание: попробуйте разные цвета и размеры
print("\n🎨 ДОПОЛНИТЕЛЬНОЕ ЗАДАНИЕ:")
print("Создайте еще одного робота с другим цветом и размером!")

# TODO: Создайте второго робота
second_robot = Robot("beta", 2, 2, "green")

plt.figure(figsize=(8, 6))
# TODO: Нарисуйте второго робота с большим размером
second_robot.draw(size=300)

plt.grid(True, alpha=0.3)
plt.xlim(-2, 10)
plt.ylim(-2, 8)
plt.title("🤖🤖 Два робота на экране!")
plt.xlabel("X координата")
plt.ylabel("Y координата")
plt.legend()
plt.show()

# Простая проверка координат подписи и точки совпадают
assert second_robot.x == 2 and second_robot.y == 2
print("🎉 Отлично! Теперь вы умеете рисовать роботов!")
# Out:
# 🎨 ТЕСТ: Рисование одного робота
# 🤖 alpha (blue) создан в (0, 0)
# ✅ Тест завершен! Робот нарисован!
#
# 🎨 ДОПОЛНИТЕЛЬНОЕ ЗАДАНИЕ:
# Создайте еще одного робота с другим цветом и размером!
# 🤖 beta (green) создан в (2, 2)
# 🎉 Отлично! Теперь вы умеете рисовать роботов!

# %%
# Блок 3.2.2: Рисование нескольких роботов
# Создаем армию роботов на одном графике!

import matplotlib.pyplot as plt
import numpy as np

class Robot:
    """Робот, который умеет рисовать себя на экране"""
    
    def __init__(self, name, start_x=0, start_y=0, color="blue"):
        self.name = name
        self.x = start_x
        self.y = start_y
        self.start_x = start_x
        self.start_y = start_y
        self.color = color
        self.steps_made = 0
        print(f"🤖 {name} ({color}) создан в ({start_x}, {start_y})")
    
    def draw(self, size=100):
        """Рисует робота на текущем графике"""
        plt.scatter(self.x, self.y, 
                   color=self.color, 
                   s=size, 
                   alpha=0.8,
                   label=self.name)
        
        plt.annotate(f'{self.name}\n({self.x},{self.y})', 
                    (self.x, self.y), 
                    xytext=(10, 10), 
                    textcoords='offset points',
                    fontsize=8,
                    bbox=dict(boxstyle="round,pad=0.3", 
                             facecolor=self.color, 
                             alpha=0.3))

# Тест: Армия роботов на одном графике
print("🎨 ТЕСТ: Армия роботов на одном графике")

# TODO: Создайте несколько роботов в разных позициях
robots = [
    Robot("Альфа", 0, 0, "red"),
    Robot("Бета", 10, 0, "blue"),  
    Robot("Гамма", 10, 10, "green"),
    Robot("Дельта", 0, 10, "orange")
]

# Рисуем всех роботов
plt.figure(figsize=(10, 8))

# TODO: Нарисуйте всех роботов в цикле
for robot in robots:
    robot.draw()

# Красивое оформление
plt.grid(True, alpha=0.3)
plt.xlim(-1, 15)
plt.ylim(-1, 12)
plt.title("🤖🤖🤖 Армия роботов готова к бою!")
plt.xlabel("X координата") 
plt.ylabel("Y координата")
plt.legend()
plt.show()

print("✅ Тест завершен! Армия нарисована!")

print("\n🎉 Отлично! Теперь вы умеете рисовать армии роботов!")
# Out:
# 🎨 ТЕСТ: Армия роботов на одном графике
# 🤖 Альфа (red) создан в (0, 0)
# 🤖 Бета (blue) создан в (10, 0)
# 🤖 Гамма (green) создан в (10, 10)
# 🤖 Дельта (orange) создан в (0, 10)
# /usr/lib/python3/dist-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 129302 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/lib/python3/dist-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 129302 missing from current font.
#   font.set_text(s, 0, flags=flags)
# ✅ Тест завершен! Армия нарисована!
#
# 🎉 Отлично! Теперь вы умеете рисовать армии роботов!

# %%
# Блок 3.2.3: Роботы до и после работы
# Показываем, как роботы изменяются!

import matplotlib.pyplot as plt
import numpy as np

class Robot:
    """Робот, который умеет рисовать себя на экране"""
    
    def __init__(self, name, start_x=0, start_y=0, color="blue"):
        self.name = name
        self.x = start_x
        self.y = start_y
        self.start_x = start_x
        self.start_y = start_y
        self.color = color
        self.steps_made = 0
        self.path = [(start_x, start_y)]  # для будущего draw_path()
        print(f"🤖 {name} ({color}) создан в ({start_x}, {start_y})")
    
    def draw(self, size=100):
        """Рисует робота на текущем графике"""
        plt.scatter(self.x, self.y, 
                   color=self.color, 
                   s=size, 
                   alpha=0.8,
                   label=self.name)
        
        plt.annotate(f'{self.name}\n({self.x},{self.y})', 
                    (self.x, self.y), 
                    xytext=(10, 10), 
                    textcoords='offset points',
                    fontsize=8,
                    bbox=dict(boxstyle="round,pad=0.3", 
                             facecolor=self.color, 
                             alpha=0.3))
    
    def move_right(self, steps=1):
        """Движение вправо на указанное количество шагов"""
        if steps <= 0:
            print(f"❌ {self.name}: нельзя двигаться на {steps} шагов!")
            return
        
        for step in range(steps):
            self.x += 1
            self.steps_made += 1
            self.path.append((self.x, self.y))
            print(f"    ➡️ {self.name} шаг {step+1} → ({self.x}, {self.y})")

# Тест: Роботы до и после работы
print("🎨 ТЕСТ: Роботы до и после работы")

# Создаем роботов для эксперимента
work_robots = [
    Robot("Рабочий-1", 2, 2, "purple"),
    Robot("Рабочий-2", 8, 3, "cyan"),
    Robot("Рабочий-3", 5, 7, "magenta")
]

# График ДО работы
plt.figure(figsize=(15, 5))

# Подграфик 1: ДО
plt.subplot(1, 2, 1)
for robot in work_robots:
    robot.draw()

plt.grid(True, alpha=0.3)
plt.xlim(0, 12)
plt.ylim(0, 12)
plt.title("ДО работы")
plt.xlabel("X")
plt.ylabel("Y")
plt.legend()

# Заставляем роботов работать
steps = [2, 3, 4]
for i, robot in enumerate(work_robots):
    robot.move_right(steps[i])
    print(f"✅ {robot.name} прошел {steps[i]} шагов вправо")

# Подграфик 2: ПОСЛЕ
plt.subplot(1, 2, 2)

# TODO: Нарисуйте роботов после работы
for robot in work_robots:
    robot.draw()

plt.grid(True, alpha=0.3)
plt.xlim(0, 12)
plt.ylim(0, 12)
plt.title("ПОСЛЕ работы")
plt.xlabel("X")
plt.ylabel("Y")
plt.legend()

plt.tight_layout()
plt.show()

print("✅ Тест завершен! Видно, как роботы поработали!")

print("\n🎉 Модуль визуализации освоен! Роботы теперь видны!")
# Out:
# 🎨 ТЕСТ: Роботы до и после работы
# 🤖 Рабочий-1 (purple) создан в (2, 2)
# 🤖 Рабочий-2 (cyan) создан в (8, 3)
# 🤖 Рабочий-3 (magenta) создан в (5, 7)
#     ➡️ Рабочий-1 шаг 1 → (3, 2)
#     ➡️ Рабочий-1 шаг 2 → (4, 2)
# ✅ Рабочий-1 прошел 2 шагов вправо
#     ➡️ Рабочий-2 шаг 1 → (9, 3)
#     ➡️ Рабочий-2 шаг 2 → (10, 3)
#     ➡️ Рабочий-2 шаг 3 → (11, 3)
# ✅ Рабочий-2 прошел 3 шагов вправо
#     ➡️ Рабочий-3 шаг 1 → (6, 7)
#     ➡️ Рабочий-3 шаг 2 → (7, 7)
#     ➡️ Рабочий-3 шаг 3 → (8, 7)
#     ➡️ Рабочий-3 шаг 4 → (9, 7)
# ✅ Рабочий-3 прошел 4 шагов вправо
# ✅ Тест завершен! Видно, как роботы поработали!
#
# 🎉 Модуль визуализации освоен! Роботы теперь видны!

# %%
# Блок 3.3.1: Переводчик команд
# Создаем робота, который понимает слова!

class AdvancedRobot:
    """Продвинутый робот с умными методами"""
    
    def __init__(self, name, start_x=0, start_y=0, color="blue"):
        self.name = name
        self.x = start_x
        self.y = start_y
        self.start_x = start_x
        self.start_y = start_y
        self.color = color
        self.steps_made = 0
        self.path = [(start_x, start_y)]
        self.commands_executed = []  # история команд
        print(f"🤖 {name} готов к приему команд!")
    
    # TODO: Создайте четыре метода движения
    def move_up(self):
        """Шаг вверх"""
        self.y += 1 # какую координату менять?
        self.steps_made += 1
        self.path.append((self.x, self.y))
        print(f"⬆️ {self.name} идет вверх → ({self.x}, {self.y})")
    
    def move_down(self):
        """Шаг вниз"""
        # TODO: Реализуйте движение вниз
        self.y -= 1
        self.steps_made += 1
        self.path.append((self.x, self.y))
        print(f"⬇️ {self.name} идет вниз → ({self.x}, {self.y})")
    
    def move_left(self):
        """Шаг влево"""
        # TODO: Реализуйте движение влево
        self.x -= 1
        self.steps_made += 1
        self.path.append((self.x, self.y))
        print(f"⬅️ {self.name} идет влево → ({self.x}, {self.y})")
    
    def move_right(self):
        """Шаг вправо"""
        # TODO: Реализуйте движение вправо
        self.x += 1
        self.steps_made += 1
        self.path.append((self.x, self.y))
        print(f"➡️ {self.name} идет вправо → ({self.x}, {self.y})")
    
    def execute_command(self, command):
        """Переводчик: превращает слова в действия"""
        # TODO: Реализуйте переводчик команд
        
        # Сохраняем команду в истории
        self.commands_executed.append(command)
        
        if command == "up":
            self.move_up()
        elif command == "down":
            self.move_down()
        elif command == "left":
            self.move_left()
        elif command == "right":
            self.move_right()
        else:
            # TODO: Обработайте неизвестную команду
            print(f"❓ {self.name}: Не знаю команду '{command}'!")
            print(f"   Доступные команды: up, down, left, right")
    
    def show_info(self):
        """Подробная информация о роботе"""
        print(f"📊 {self.name}:")
        print(f"   📍 Позиция: ({self.x}, {self.y})")
        print(f"   🏠 Дом: ({self.start_x}, {self.start_y})")
        print(f"   👣 Шагов: {self.steps_made}")
        print(f"   📜 Команд выполнено: {len(self.commands_executed)}")
        if self.commands_executed:
            print(f"   🔤 Последние команды: {self.commands_executed[-5:]}")

# ТЕСТ 1: Основные движения
print("🧪 ТЕСТ 1: Проверяем основные движения")

# TODO: Создайте робота для тестирования
test_robot = AdvancedRobot("Тестер", 0, 0, "red")

# Тестируем каждое направление
print("\nТестируем все направления:")
test_robot.move_up()
test_robot.move_right()
test_robot.move_down()
test_robot.move_left()

test_robot.show_info()

# ТЕСТ 2: Переводчик команд
print("\n🧪 ТЕСТ 2: Тестируем переводчик команд")

# TODO: Создайте робота-переводчика
translator_robot = AdvancedRobot("Переводчик", 5, 5, "blue")

# Тестируем команды словами
print("\nТестируем команды словами:")
translator_robot.execute_command("up")  # up
translator_robot.execute_command("right")  # right
translator_robot.execute_command("down")  # down
translator_robot.execute_command("left")  # left

# Тестируем неизвестную команду
translator_robot.execute_command("неизвестно")

translator_robot.show_info()

print(f"\n🎉 Переводчик команд работает! Робот понимает слова!")
# Out:
# 🧪 ТЕСТ 1: Проверяем основные движения
# 🤖 Тестер готов к приему команд!
#
# Тестируем все направления:
# ⬆️ Тестер идет вверх → (0, 1)
# ➡️ Тестер идет вправо → (1, 1)
# ⬇️ Тестер идет вниз → (1, 0)
# ⬅️ Тестер идет влево → (0, 0)
# 📊 Тестер:
#    📍 Позиция: (0, 0)
#    🏠 Дом: (0, 0)
#    👣 Шагов: 4
#    📜 Команд выполнено: 0
#
# 🧪 ТЕСТ 2: Тестируем переводчик команд
# 🤖 Переводчик готов к приему команд!
#
# Тестируем команды словами:
# ⬆️ Переводчик идет вверх → (5, 6)
# ⬅️ Переводчик идет влево → (4, 6)
# ⬇️ Переводчик идет вниз → (4, 5)
# ➡️ Переводчик идет вправо → (5, 5)
# ❓ Переводчик: Не знаю команду 'неизвестно'!
#    Доступные команды: up, down, left, right
# 📊 Переводчик:
#    📍 Позиция: (5, 5)
#    🏠 Дом: (5, 5)
#    👣 Шагов: 4
#    📜 Команд выполнено: 5
#    🔤 Последние команды: ['up', 'right', 'down', 'left', 'неизвестно']
#
# 🎉 Переводчик команд работает! Робот понимает слова!

# %%
# Блок 3.3.2: Последовательности команд
# Робот выполняет списки команд!

class AdvancedRobot:
    """Продвинутый робот с умными методами"""
    
    def __init__(self, name, start_x=0, start_y=0, color="blue"):
        self.name = name
        self.x = start_x
        self.y = start_y
        self.start_x = start_x
        self.start_y = start_y
        self.color = color
        self.steps_made = 0
        self.path = [(start_x, start_y)]
        self.commands_executed = []  # история команд
        print(f"🤖 {name} готов к приему команд!")
    
    def move_up(self):
        """Шаг вверх"""
        self.y += 1
        self.steps_made += 1
        self.path.append((self.x, self.y))
        print(f"⬆️ {self.name} идет вверх → ({self.x}, {self.y})")
    
    def move_down(self):
        """Шаг вниз"""
        self.y -= 1
        self.steps_made += 1
        self.path.append((self.x, self.y))
        print(f"⬇️ {self.name} идет вниз → ({self.x}, {self.y})")
    
    def move_left(self):
        """Шаг влево"""
        self.x -= 1
        self.steps_made += 1
        self.path.append((self.x, self.y))
        print(f"⬅️ {self.name} идет влево → ({self.x}, {self.y})")
    
    def move_right(self):
        """Шаг вправо"""
        self.x += 1
        self.steps_made += 1
        self.path.append((self.x, self.y))
        print(f"➡️ {self.name} идет вправо → ({self.x}, {self.y})")
    
    def execute_command(self, command):
        """Переводчик: превращает слова в действия"""
        # Сохраняем команду в истории
        self.commands_executed.append(command)
        
        if command == "up":
            self.move_up()
        elif command == "down":
            self.move_down()
        elif command == "left":
            self.move_left()
        elif command == "right":
            self.move_right()
        else:
            print(f"❓ {self.name}: Не знаю команду '{command}'!")
            print(f"   Доступные команды: up, down, left, right")
    
    def execute_sequence(self, commands):
        """Выполняет список команд"""
        print(f"📋 {self.name} получил {len(commands)} команд: {commands}")
        
        # TODO: Выполните все команды из списка
        for i, command in enumerate(commands):
            print(f"  Команда {i+1}/{len(commands)}: {command}")
            self.execute_command(command)  # вызовите execute_command
        
        print(f"✅ {self.name} выполнил все команды!")
    
    def show_info(self):
        """Подробная информация о роботе"""
        print(f"📊 {self.name}:")
        print(f"   📍 Позиция: ({self.x}, {self.y})")
        print(f"   🏠 Дом: ({self.start_x}, {self.start_y})")
        print(f"   👣 Шагов: {self.steps_made}")
        print(f"   📜 Команд выполнено: {len(self.commands_executed)}")
        if self.commands_executed:
            print(f"   🔤 Последние команды: {self.commands_executed[-5:]}")

# ТЕСТ: Последовательности команд
print("🧪 ТЕСТ: Последовательности команд")

# TODO: Создайте робота для последовательностей
sequence_robot = AdvancedRobot("Последователь", 0, 0, "green")

# Создаем команды для квадрата
square_commands = ["right", "right", "up", "up", "left", "left", "down", "down"]

print(f"\nРисуем квадрат:")
sequence_robot.execute_sequence(square_commands)  # square_commands

print(f"\nТелепортируемся и рисуем еще один квадрат:")
sequence_robot.x, sequence_robot.y = 10, 10  # телепорт
sequence_robot.execute_sequence(square_commands)  # square_commands

sequence_robot.show_info()

print(f"\n🎉 Робот умеет выполнять последовательности команд!")
# Out:
# 🧪 ТЕСТ: Последовательности команд
# 🤖 Последователь готов к приему команд!
#
# Рисуем квадрат:
# 📋 Последователь получил 8 команд: ['right', 'right', 'up', 'up', 'left', 'left', 'down', 'down']
#   Команда 1/8: right
# ➡️ Последователь идет вправо → (1, 0)
#   Команда 2/8: right
# ➡️ Последователь идет вправо → (2, 0)
#   Команда 3/8: up
# ⬆️ Последователь идет вверх → (2, 1)
#   Команда 4/8: up
# ⬆️ Последователь идет вверх → (2, 2)
#   Команда 5/8: left
# ⬅️ Последователь идет влево → (1, 2)
#   Команда 6/8: left
# ⬅️ Последователь идет влево → (0, 2)
#   Команда 7/8: down
# ⬇️ Последователь идет вниз → (0, 1)
#   Команда 8/8: down
# ⬇️ Последователь идет вниз → (0, 0)
# ✅ Последователь выполнил все команды!
#
# Телепортируемся и рисуем еще один квадрат:
# 📋 Последователь получил 8 команд: ['right', 'right', 'up', 'up', 'left', 'left', 'down', 'down']
#   Команда 1/8: right
# ➡️ Последователь идет вправо → (11, 10)
#   Команда 2/8: right
# ➡️ Последователь идет вправо → (12, 10)
#   Команда 3/8: up
# ⬆️ Последователь идет вверх → (12, 11)
#   Команда 4/8: up
# ⬆️ Последователь идет вверх → (12, 12)
#   Команда 5/8: left
# ⬅️ Последователь идет влево → (11, 12)
#   Команда 6/8: left
# ⬅️ Последователь идет влево → (10, 12)
#   Команда 7/8: down
# ⬇️ Последователь идет вниз → (10, 11)
#   Команда 8/8: down
# ⬇️ Последователь идет вниз → (10, 10)
# ✅ Последователь выполнил все команды!
# 📊 Последователь:
#    📍 Позиция: (10, 10)
#    🏠 Дом: (0, 0)
#    👣 Шагов: 16
#    📜 Команд выполнено: 16
#    🔤 Последние команды: ['up', 'left', 'left', 'down', 'down']
#
# 🎉 Робот умеет выполнять последовательности команд!

# %%
# Блок 3.3.3: Визуализация продвинутых роботов
# Рисуем пути и позиции роботов!

import matplotlib.pyplot as plt

class AdvancedRobot:
    """Продвинутый робот с умными методами"""
    
    def __init__(self, name, start_x=0, start_y=0, color="blue"):
        self.name = name
        self.x = start_x
        self.y = start_y
        self.start_x = start_x
        self.start_y = start_y
        self.color = color
        self.steps_made = 0
        self.path = [(start_x, start_y)]
        self.commands_executed = []  # история команд
        print(f"🤖 {name} готов к приему команд!")
    
    def move_up(self):
        """Шаг вверх"""
        self.y += 1
        self.steps_made += 1
        self.path.append((self.x, self.y))
        print(f"⬆️ {self.name} идет вверх → ({self.x}, {self.y})")
    
    def move_down(self):
        """Шаг вниз"""
        self.y -= 1
        self.steps_made += 1
        self.path.append((self.x, self.y))
        print(f"⬇️ {self.name} идет вниз → ({self.x}, {self.y})")
    
    def move_left(self):
        """Шаг влево"""
        self.x -= 1
        self.steps_made += 1
        self.path.append((self.x, self.y))
        print(f"⬅️ {self.name} идет влево → ({self.x}, {self.y})")
    
    def move_right(self):
        """Шаг вправо"""
        self.x += 1
        self.steps_made += 1
        self.path.append((self.x, self.y))
        print(f"➡️ {self.name} идет вправо → ({self.x}, {self.y})")
    
    def execute_command(self, command):
        """Переводчик: превращает слова в действия"""
        # Сохраняем команду в истории
        self.commands_executed.append(command)
        
        if command == "up":
            self.move_up()
        elif command == "down":
            self.move_down()
        elif command == "left":
            self.move_left()
        elif command == "right":
            self.move_right()
        else:
            print(f"❓ {self.name}: Не знаю команду '{command}'!")
            print(f"   Доступные команды: up, down, left, right")
    
    def execute_sequence(self, commands):
        """Выполняет список команд"""
        print(f"📋 {self.name} получил {len(commands)} команд: {commands}")
        
        # Выполняем все команды из списка
        for i, command in enumerate(commands):
            print(f"  Команда {i+1}/{len(commands)}: {command}")
            self.execute_command(command)
        
        print(f"✅ {self.name} выполнил все команды!")
    
    def draw(self):
        """Рисует робота и его путь"""
        # TODO: Нарисуйте путь робота
        if len(self.path) > 1:
            x_coords = [p[0] for p in self.path]
            y_coords = [p[1] for p in self.path]
            plt.plot(x_coords, y_coords, 
                    color=self.color, 
                    linewidth=2, 
                    alpha=0.6, 
                    linestyle='--')
        
        # TODO: Нарисуйте текущую позицию
        plt.scatter(self.x, self.y, 
                   color=self.color, 
                   s=200, 
                   alpha=0.9,
                   label=self.name)
        
        # TODO: Добавьте подпись
        plt.annotate(f'{self.name}\n({self.x},{self.y})', 
                    (self.start_x, self.start_y), 
                    xytext=(10, 10), 
                    textcoords='offset points',
                    fontsize=9)
    
    def show_info(self):
        """Подробная информация о роботе"""
        print(f"📊 {self.name}:")
        print(f"   📍 Позиция: ({self.x}, {self.y})")
        print(f"   🏠 Дом: ({self.start_x}, {self.start_y})")
        print(f"   👣 Шагов: {self.steps_made}")
        print(f"   📜 Команд выполнено: {len(self.commands_executed)}")
        if self.commands_executed:
            print(f"   🔤 Последние команды: {self.commands_executed[-5:]}")

# ТЕСТ: Визуализация всех роботов
print("🧪 ТЕСТ: Визуализация результатов")

# Создаем разных роботов
test_robot = AdvancedRobot("Тестер", 0, 0, "red")
translator_robot = AdvancedRobot("Переводчик", 5, 5, "blue")
sequence_robot = AdvancedRobot("Последователь", 10, 10, "green")

# Даем им разные задания
test_robot.move_up()
test_robot.move_right()

translator_robot.execute_command("up")
translator_robot.execute_command("right")

square_commands = ["right", "right", "up", "up", "left", "left", "down", "down"]
sequence_robot.execute_sequence(square_commands)

# Рисуем всех роботов
robots = [test_robot, translator_robot, sequence_robot]

plt.figure(figsize=(12, 8))

# TODO: Нарисуйте всех роботов в цикле
for robot in robots:
    robot.draw()

plt.grid(True, alpha=0.3)
plt.xlim(-2, 15)
plt.ylim(-2, 15)
plt.title("🤖 Продвинутые роботы и их пути")
plt.xlabel("X координата")
plt.ylabel("Y координата")
plt.legend()
plt.show()

# Итоговая статистика
print(f"\n📊 ИТОГОВАЯ СТАТИСТИКА:")
total_steps = sum(robot.steps_made for robot in robots)
total_commands = sum(len(robot.commands_executed) for robot in robots)

print(f"   🤖 Роботов протестировано: {len(robots)}")
print(f"   👣 Общее количество шагов: {total_steps}")
print(f"   📜 Общее количество команд: {total_commands}")
print(f"   📊 Среднее шагов на робота: {total_steps/len(robots):.1f}")

print(f"\n🎉 Все тесты пройдены! Роботы стали умнее!")
# Out:
# 🧪 ТЕСТ: Визуализация результатов
# 🤖 Тестер готов к приему команд!
# 🤖 Переводчик готов к приему команд!
# 🤖 Последователь готов к приему команд!
# ⬆️ Тестер идет вверх → (0, 1)
# ➡️ Тестер идет вправо → (1, 1)
# ⬆️ Переводчик идет вверх → (5, 6)
# ➡️ Переводчик идет вправо → (6, 6)
# 📋 Последователь получил 8 команд: ['right', 'right', 'up', 'up', 'left', 'left', 'down', 'down']
#   Команда 1/8: right
# ➡️ Последователь идет вправо → (11, 10)
#   Команда 2/8: right
# ➡️ Последователь идет вправо → (12, 10)
#   Команда 3/8: up
# ⬆️ Последователь идет вверх → (12, 11)
#   Команда 4/8: up
# ⬆️ Последователь идет вверх → (12, 12)
#   Команда 5/8: left
# ⬅️ Последователь идет влево → (11, 12)
#   Команда 6/8: left
# ⬅️ Последователь идет влево → (10, 12)
#   Команда 7/8: down
# ⬇️ Последователь идет вниз → (10, 11)
#   Команда 8/8: down
# ⬇️ Последователь идет вниз → (10, 10)
# ✅ Последователь выполнил все команды!
# /usr/lib/python3/dist-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 129302 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/lib/python3/dist-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 129302 missing from current font.
#   font.set_text(s, 0, flags=flags)
# 📊 ИТОГОВАЯ СТАТИСТИКА:
#    🤖 Роботов протестировано: 3
#    👣 Общее количество шагов: 12
#    📜 Общее количество команд: 10
#    📊 Среднее шагов на робота: 4.0
#
# 🎉 Все тесты пройдены! Роботы стали умнее!

# %%
# Блок 4.1: Навигация к цели - роботы планируют маршрут!
# Учим роботов находить путь самостоятельно

import matplotlib.pyplot as plt
import math

class NavigatorRobot:
    """Робот-навигатор, который умеет планировать маршруты"""
    
    def __init__(self, name, start_x=0, start_y=0, color="blue"):
        self.name = name
        self.x = start_x
        self.y = start_y
        self.start_x = start_x
        self.start_y = start_y
        self.color = color
        self.steps_made = 0
        self.path = [(start_x, start_y)]
        self.targets_reached = 0
        print(f"🧭 {name} готов к навигации из ({start_x}, {start_y})")
    
    def move_up(self):
        self.y += 1
        self.steps_made += 1
        self.path.append((self.x, self.y))
    
    def move_down(self):
        self.y -= 1
        self.steps_made += 1
        self.path.append((self.x, self.y))
    
    def move_left(self):
        self.x -= 1
        self.steps_made += 1
        self.path.append((self.x, self.y))
    
    def move_right(self):
        self.x += 1
        self.steps_made += 1
        self.path.append((self.x, self.y))
    
    def execute_command(self, command):
        """Выполняет одну команду"""
        if command == "up":
            self.move_up()
        elif command == "down":
            self.move_down()
        elif command == "left":
            self.move_left()
        elif command == "right":
            self.move_right()
    
    def calculate_distance(self, target_x, target_y):
        """Вычисляет расстояние до цели"""
        # TODO: Используйте формулу расстояния
        dx = target_x - self.x
        dy = target_y - self.y
        distance = math.sqrt(dx * dx + dy * dy)
        return distance
    
    def generate_path_commands(self, target_x, target_y):
        """Генерирует список команд для достижения цели"""
        commands = []
        
        # TODO: Вычислите сколько шагов нужно по каждой оси
        dx = target_x - self.x  # сколько по X (I prefer (self, other) --> other.x - self.x)
        dy = target_y - self.y  # сколько по Y (same)
        
        print(f"📐 {self.name}: нужно пройти Δx={dx}, Δy={dy}")
        
        # TODO: Генерируем команды для движения по X
        if dx > 0:  # нужно идти вправо
            commands.extend(["right"] * dx)  # добавляем команды "right"
        elif dx < 0:  # нужно идти влево
            commands.extend(["left"] * abs(dx))  # добавляем команды "left"
        
        # TODO: Генерируем команды для движения по Y
        if dy > 0:  # нужно идти вверх
            commands.extend(["up"] * dy)
        elif dy < 0:  # нужно идти вниз  
            commands.extend(["down"] * abs(dy))
        
        return commands
    
    def move_to_target(self, target_x, target_y):
        """Главный метод: планирует и выполняет маршрут к цели"""
        print(f"\n🎯 {self.name} планирует маршрут из ({self.x}, {self.y}) в ({target_x}, {target_y})")
        
        # Вычисляем расстояние
        distance = self.calculate_distance(target_x, target_y)
        print(f"📏 Расстояние до цели: {distance:.2f}")
        
        # Генерируем команды
        commands = self.generate_path_commands(target_x, target_y)
        print(f"🗺️ План маршрута: {commands}")
        print(f"📊 Общее количество шагов: {len(commands)}")
        
        # Выполняем команды
        print(f"🚶 Начинаем движение...")
        for i, command in enumerate(commands):
            self.execute_command(command)
            print(f"   Шаг {i+1}: {command} → ({self.x}, {self.y})")
        
        # Проверяем успех
        if self.x == target_x and self.y == target_y:
            self.targets_reached += 1
            print(f"✅ {self.name} достиг цели ({target_x}, {target_y})!")
        else:
            print(f"❌ {self.name} промахнулся! Цель: ({target_x}, {target_y}), факт: ({self.x}, {self.y})")
        
        return self.x == target_x and self.y == target_y
    
    def show_info(self):
        """Информация о навигаторе"""
        print(f"🧭 {self.name}:")
        print(f"   📍 Текущая позиция: ({self.x}, {self.y})")
        print(f"   🏠 Стартовая позиция: ({self.start_x}, {self.start_y})")
        print(f"   👣 Шагов сделано: {self.steps_made}")
        print(f"   🎯 Целей достигнуто: {self.targets_reached}")
    
    def draw(self, targets=None):
        """Рисует робота, его путь и цели"""
        # Путь робота
        if len(self.path) > 1:
            x_coords = [p[0] for p in self.path]
            y_coords = [p[1] for p in self.path]
            plt.plot(x_coords, y_coords, 
                    color=self.color, 
                    linewidth=2, 
                    alpha=0.7,
                    label=f'{self.name} путь')
        
        # Стартовая позиция
        plt.scatter(self.start_x, self.start_y, 
                   color=self.color, 
                   s=150, 
                   marker='^', 
                   alpha=0.8,
                   label=f'{self.name} старт')
        
        # Текущая позиция
        plt.scatter(self.x, self.y, 
                   color=self.color, 
                   s=200, 
                   marker='o',
                   alpha=0.9,
                   label=f'{self.name}')
        
        # Цели (если переданы)
        if targets:
            for i, (tx, ty) in enumerate(targets):
                plt.scatter(tx, ty, 
                           color='red', 
                           s=150, 
                           marker='*',
                           alpha=0.8)
                plt.annotate(f'Цель {i+1}', (tx, ty), 
                           xytext=(5, 5), 
                           textcoords='offset points')

# ТЕСТ 1: Простая навигация
print("🧪 ТЕСТ 1: Простая навигация к одной цели")

# TODO: Создайте навигатора
navigator = NavigatorRobot("Navi", 1, 1, "blue")

# TODO: Отправьте его к цели (5, 3)
target_x, target_y = 5, 3
success = navigator.move_to_target(target_x, target_y)

navigator.show_info()
print(f"Результат: {'✅ Успех' if success else '❌ Неудача'}")

# ТЕСТ 2: Множественные цели
print("\n🧪 ТЕСТ 2: Путешествие по множественным целям")

# TODO: Создайте нового робота-путешественника
traveler = NavigatorRobot("Traveler", 5, 5, "green")

# Список целей для посещения
destinations = [(3, 4), (7, 2), (1, 6), (8, 8)]

print(f"🗺️ {traveler.name} должен посетить {len(destinations)} мест:")
for i, (x, y) in enumerate(destinations):
    print(f"   {i+1}. ({x}, {y})")

# TODO: Посетите все цели по очереди
successful_trips = 0
for i, (target_x, target_y) in enumerate(destinations):
    print(f"\n--- ПОЕЗДКА {i+1} К ({target_x}, {target_y}) ---")
    success = traveler.move_to_target(target_x, target_y)
    if success:
        successful_trips += 1

traveler.show_info()
print(f"\n📊 Статистика путешествий:")
print(f"   🎯 Целей назначено: {len(destinations)}")
print(f"   ✅ Целей достигнуто: {successful_trips}")
print(f"   📈 Процент успеха: {successful_trips/len(destinations)*100:.1f}%")

# ТЕСТ 3: Навигация в разные стороны
print("\n🧪 ТЕСТ 3: Навигация во все стороны света")

# TODO: Создайте робота-исследователя
explorer = NavigatorRobot("Explorer", 5, 0, "red")

# Цели во всех направлениях от центра
directions_targets = [
    (10, 5),  # восток
    (5, 10),  # север  
    (0, 5),   # запад
    (5, 0),   # юг
    (5, 5)    # возврат в центр
]

direction_names = ["Восток", "Север", "Запад", "Юг", "Центр"]

for i, ((target_x, target_y), direction) in enumerate(zip(directions_targets, direction_names)):
    print(f"\n--- ИССЛЕДОВАНИЕ: {direction.upper()} ({target_x}, {target_y}) ---")
    explorer.move_to_target(target_x, target_y)

explorer.show_info()

# ТЕСТ 4: Визуализация всех маршрутов
print("\n🧪 ТЕСТ 4: Визуализация навигации")

robots = [navigator, traveler, explorer]

plt.figure(figsize=(12, 10))

# Рисуем всех роботов
for robot in robots:
    if robot == traveler:
        robot.draw(targets=destinations)
    elif robot == explorer:
        robot.draw(targets=directions_targets)
    else:
        robot.draw(targets=[(5, 3)])

plt.grid(True, alpha=0.3)
plt.xlim(-1, 12)
plt.ylim(-1, 12)
plt.title("🧭 Навигационные маршруты роботов")
plt.xlabel("X координата")
plt.ylabel("Y координата")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# Итоговая статистика
print(f"\n📊 ИТОГОВАЯ СТАТИСТИКА НАВИГАЦИИ:")
total_steps = sum(robot.steps_made for robot in robots)
total_targets = sum(robot.targets_reached for robot in robots)

print(f"   🤖 Роботов-навигаторов: {len(robots)}")
print(f"   👣 Общее количество шагов: {total_steps}")
print(f"   🎯 Общее количество целей: {total_targets}")
print(f"   📊 Среднее шагов на цель: {total_steps/total_targets:.1f}")

# Самый эффективный навигатор
most_efficient = min(robots, key=lambda r: r.steps_made/max(r.targets_reached, 1))
print(f"   🏆 Самый эффективный: {most_efficient.name} ({most_efficient.steps_made/max(most_efficient.targets_reached, 1):.1f} шагов/цель)")

print(f"\n🎉 Навигационная система успешно протестирована!")
# Out:
# 🧪 ТЕСТ 1: Простая навигация к одной цели
# 🧭 Navi готов к навигации из (1, 1)
#
# 🎯 Navi планирует маршрут из (1, 1) в (5, 3)
# 📏 Расстояние до цели: 4.47
# 📐 Navi: нужно пройти Δx=4, Δy=2
# 🗺️ План маршрута: ['right', 'right', 'right', 'right', 'up', 'up']
# 📊 Общее количество шагов: 6
# 🚶 Начинаем движение...
#    Шаг 1: right → (2, 1)
#    Шаг 2: right → (3, 1)
#    Шаг 3: right → (4, 1)
#    Шаг 4: right → (5, 1)
#    Шаг 5: up → (5, 2)
#    Шаг 6: up → (5, 3)
# ✅ Navi достиг цели (5, 3)!
# 🧭 Navi:
#    📍 Текущая позиция: (5, 3)
#    🏠 Стартовая позиция: (1, 1)
#    👣 Шагов сделано: 6
#    🎯 Целей достигнуто: 1
# Результат: ✅ Успех
#
# 🧪 ТЕСТ 2: Путешествие по множественным целям
# 🧭 Traveler готов к навигации из (5, 5)
# 🗺️ Traveler должен посетить 4 мест:
#    1. (3, 4)
#    2. (7, 2)
#    3. (1, 6)
#    4. (8, 8)
#
# --- ПОЕЗДКА 1 К (3, 4) ---
#
# 🎯 Traveler планирует маршрут из (5, 5) в (3, 4)
# 📏 Расстояние до цели: 2.24
# 📐 Traveler: нужно пройти Δx=-2, Δy=-1
# 🗺️ План маршрута: ['left', 'left', 'down']
# 📊 Общее количество шагов: 3
# 🚶 Начинаем движение...
#    Шаг 1: left → (4, 5)
#    Шаг 2: left → (3, 5)
#    Шаг 3: down → (3, 4)
# ✅ Traveler достиг цели (3, 4)!
#
# --- ПОЕЗДКА 2 К (7, 2) ---
#
# 🎯 Traveler планирует маршрут из (3, 4) в (7, 2)
# 📏 Расстояние до цели: 4.47
# 📐 Traveler: нужно пройти Δx=4, Δy=-2
# 🗺️ План маршрута: ['right', 'right', 'right', 'right', 'down', 'down']
# 📊 Общее количество шагов: 6
# 🚶 Начинаем движение...
#    Шаг 1: right → (4, 4)
#    Шаг 2: right → (5, 4)
#    Шаг 3: right → (6, 4)
#    Шаг 4: right → (7, 4)
#    Шаг 5: down → (7, 3)
#    Шаг 6: down → (7, 2)
# ✅ Traveler достиг цели (7, 2)!
#
# --- ПОЕЗДКА 3 К (1, 6) ---
#
# 🎯 Traveler планирует маршрут из (7, 2) в (1, 6)
# 📏 Расстояние до цели: 7.21
# 📐 Traveler: нужно пройти Δx=-6, Δy=4
# 🗺️ План маршрута: ['left', 'left', 'left', 'left', 'left', 'left', 'up', 'up', 'up', 'up']
# 📊 Общее количество шагов: 10
# 🚶 Начинаем движение...
#    Шаг 1: left → (6, 2)
#    Шаг 2: left → (5, 2)
#    Шаг 3: left → (4, 2)
#    Шаг 4: left → (3, 2)
#    Шаг 5: left → (2, 2)
#    Шаг 6: left → (1, 2)
#    Шаг 7: up → (1, 3)
#    Шаг 8: up → (1, 4)
#    Шаг 9: up → (1, 5)
#    Шаг 10: up → (1, 6)
# ✅ Traveler достиг цели (1, 6)!
#
# --- ПОЕЗДКА 4 К (8, 8) ---
#
# 🎯 Traveler планирует маршрут из (1, 6) в (8, 8)
# 📏 Расстояние до цели: 7.28
# 📐 Traveler: нужно пройти Δx=7, Δy=2
# 🗺️ План маршрута: ['right', 'right', 'right', 'right', 'right', 'right', 'right', 'up', 'up']
# 📊 Общее количество шагов: 9
# 🚶 Начинаем движение...
#    Шаг 1: right → (2, 6)
#    Шаг 2: right → (3, 6)
#    Шаг 3: right → (4, 6)
#    Шаг 4: right → (5, 6)
#    Шаг 5: right → (6, 6)
#    Шаг 6: right → (7, 6)
#    Шаг 7: right → (8, 6)
#    Шаг 8: up → (8, 7)
#    Шаг 9: up → (8, 8)
# ✅ Traveler достиг цели (8, 8)!
# 🧭 Traveler:
#    📍 Текущая позиция: (8, 8)
#    🏠 Стартовая позиция: (5, 5)
#    👣 Шагов сделано: 28
#    🎯 Целей достигнуто: 4
#
# 📊 Статистика путешествий:
#    🎯 Целей назначено: 4
#    ✅ Целей достигнуто: 4
#    📈 Процент успеха: 100.0%
#
# 🧪 ТЕСТ 3: Навигация во все стороны света
# 🧭 Explorer готов к навигации из (5, 0)
#
# --- ИССЛЕДОВАНИЕ: ВОСТОК (10, 5) ---
#
# 🎯 Explorer планирует маршрут из (5, 0) в (10, 5)
# 📏 Расстояние до цели: 7.07
# 📐 Explorer: нужно пройти Δx=5, Δy=5
# 🗺️ План маршрута: ['right', 'right', 'right', 'right', 'right', 'up', 'up', 'up', 'up', 'up']
# 📊 Общее количество шагов: 10
# 🚶 Начинаем движение...
#    Шаг 1: right → (6, 0)
#    Шаг 2: right → (7, 0)
#    Шаг 3: right → (8, 0)
#    Шаг 4: right → (9, 0)
#    Шаг 5: right → (10, 0)
#    Шаг 6: up → (10, 1)
#    Шаг 7: up → (10, 2)
#    Шаг 8: up → (10, 3)
#    Шаг 9: up → (10, 4)
#    Шаг 10: up → (10, 5)
# ✅ Explorer достиг цели (10, 5)!
#
# --- ИССЛЕДОВАНИЕ: СЕВЕР (5, 10) ---
#
# 🎯 Explorer планирует маршрут из (10, 5) в (5, 10)
# 📏 Расстояние до цели: 7.07
# 📐 Explorer: нужно пройти Δx=-5, Δy=5
# 🗺️ План маршрута: ['left', 'left', 'left', 'left', 'left', 'up', 'up', 'up', 'up', 'up']
# 📊 Общее количество шагов: 10
# 🚶 Начинаем движение...
#    Шаг 1: left → (9, 5)
#    Шаг 2: left → (8, 5)
#    Шаг 3: left → (7, 5)
#    Шаг 4: left → (6, 5)
#    Шаг 5: left → (5, 5)
#    Шаг 6: up → (5, 6)
#    Шаг 7: up → (5, 7)
#    Шаг 8: up → (5, 8)
#    Шаг 9: up → (5, 9)
#    Шаг 10: up → (5, 10)
# ✅ Explorer достиг цели (5, 10)!
#
# --- ИССЛЕДОВАНИЕ: ЗАПАД (0, 5) ---
#
# 🎯 Explorer планирует маршрут из (5, 10) в (0, 5)
# 📏 Расстояние до цели: 7.07
# 📐 Explorer: нужно пройти Δx=-5, Δy=-5
# 🗺️ План маршрута: ['left', 'left', 'left', 'left', 'left', 'down', 'down', 'down', 'down', 'down']
# 📊 Общее количество шагов: 10
# 🚶 Начинаем движение...
#    Шаг 1: left → (4, 10)
#    Шаг 2: left → (3, 10)
#    Шаг 3: left → (2, 10)
#    Шаг 4: left → (1, 10)
#    Шаг 5: left → (0, 10)
#    Шаг 6: down → (0, 9)
#    Шаг 7: down → (0, 8)
#    Шаг 8: down → (0, 7)
#    Шаг 9: down → (0, 6)
#    Шаг 10: down → (0, 5)
# ✅ Explorer достиг цели (0, 5)!
#
# --- ИССЛЕДОВАНИЕ: ЮГ (5, 0) ---
#
# 🎯 Explorer планирует маршрут из (0, 5) в (5, 0)
# 📏 Расстояние до цели: 7.07
# 📐 Explorer: нужно пройти Δx=5, Δy=-5
# 🗺️ План маршрута: ['right', 'right', 'right', 'right', 'right', 'down', 'down', 'down', 'down', 'down']
# 📊 Общее количество шагов: 10
# 🚶 Начинаем движение...
#    Шаг 1: right → (1, 5)
#    Шаг 2: right → (2, 5)
#    Шаг 3: right → (3, 5)
#    Шаг 4: right → (4, 5)
#    Шаг 5: right → (5, 5)
#    Шаг 6: down → (5, 4)
#    Шаг 7: down → (5, 3)
#    Шаг 8: down → (5, 2)
#    Шаг 9: down → (5, 1)
#    Шаг 10: down → (5, 0)
# ✅ Explorer достиг цели (5, 0)!
#
# --- ИССЛЕДОВАНИЕ: ЦЕНТР (5, 5) ---
#
# 🎯 Explorer планирует маршрут из (5, 0) в (5, 5)
# 📏 Расстояние до цели: 5.00
# 📐 Explorer: нужно пройти Δx=0, Δy=5
# 🗺️ План маршрута: ['up', 'up', 'up', 'up', 'up']
# 📊 Общее количество шагов: 5
# 🚶 Начинаем движение...
#    Шаг 1: up → (5, 1)
#    Шаг 2: up → (5, 2)
#    Шаг 3: up → (5, 3)
#    Шаг 4: up → (5, 4)
#    Шаг 5: up → (5, 5)
# ✅ Explorer достиг цели (5, 5)!
# 🧭 Explorer:
#    📍 Текущая позиция: (5, 5)
#    🏠 Стартовая позиция: (5, 0)
#    👣 Шагов сделано: 45
#    🎯 Целей достигнуто: 5
#
# 🧪 ТЕСТ 4: Визуализация навигации
# 📊 ИТОГОВАЯ СТАТИСТИКА НАВИГАЦИИ:
#    🤖 Роботов-навигаторов: 3
#    👣 Общее количество шагов: 79
#    🎯 Общее количество целей: 10
#    📊 Среднее шагов на цель: 7.9
#    🏆 Самый эффективный: Navi (6.0 шагов/цель)
#
# 🎉 Навигационная система успешно протестирована!
